# %%
## Run when initialise the code


from pandas import DataFrame

from shapely.ops import nearest_points

from geopandas import GeoDataFrame
from shapely.geometry import  MultiPolygon,MultiLineString, MultiPoint
from shapely.ops import linemerge, unary_union,split,substring,snap
from shapely.strtree import STRtree
from shapely.geometry.base import BaseGeometry
from shapely.prepared import prep

import geopandas as gpd
from shapely.geometry import Point, LineString,  Polygon, LinearRing

import pandas as pd

import os
import requests
from tqdm import tqdm
from sklearn.cluster import DBSCAN

import numpy as np
import math
from math import log2

from itertools import groupby, combinations
from collections import defaultdict

import warnings
from dataclasses import dataclass
from typing import Set


import networkx as nx


warnings.filterwarnings(action='ignore')

pjr_loc = os.path.dirname(os.getcwd())
project_crs = 'epsg:3857'
place = 'Turin,Italy'
place_folder = f'{pjr_loc}/places'
os.makedirs(place_folder , exist_ok=True)
data_folder = f'{place_folder}/{place.replace(",","_")}'
os.makedirs(data_folder, exist_ok=True)
test_folder = f'{data_folder}/test'
os.makedirs(test_folder, exist_ok=True)
test_temp_folder = f'{test_folder}/test_temp'
os.makedirs(test_temp_folder, exist_ok=True)

def __get_bbox_from_nominatim(place_name):
    """
    Fetches the bounding box of a place using the Nominatim API.

    Parameters:
        place_name (str): The name of the place to search.

    Returns:
        tuple: (south, north, west, east) as floats.
    """
    url = "https://nominatim.openstreetmap.org/search"
    params = {
        "q": place_name,
        "format": "json",
        "limit": 1
    }
    headers = {
        "User-Agent": "GeoResearcher/1.0 (achituv@ariel.ac.il)"
    }

    response = requests.get(url, params=params, headers=headers)
    response.raise_for_status()
    results = response.json()

    if not results:
        raise ValueError(f"No results found for place: {place_name}")

    bbox = results[0]["boundingbox"]
    return float(bbox[0]), float(bbox[1]), float(bbox[2]), float(bbox[3])

def download_osm_roads_bbox(place_name, highway_tags=None):
    """
    Downloads OpenStreetMap road data within the bounding box of a given place name.

    Parameters:
    ----------
    place_name : str
        Name of the place to retrieve the road data for. The function uses the Nominatim API
        to geocode this name into a bounding box.

    highway_tags : list of str, optional
        A list of OSM 'highway' tag values to filter the types of roads to download.
        If not provided, a default list including common road and path types is used:
        ['primary','footway','pedestrian','cycleway','path','secondary',
         'tertiary','unclassified','residential','service','living_street','steps']

    Returns:
    -------
    GeoDataFrame
        A GeoDataFrame containing the downloaded road features within the bounding box.
        Each feature includes its geometry (LineString), 'osmid' (OSM way ID), and other OSM tags.
        CRS is EPSG:4326.
    """
    if highway_tags is None:
        highway_tags = [
            'primary', 'footway', 'pedestrian', 'cycleway', 'path',
            'secondary', 'tertiary', 'unclassified', 'residential',
            'service', 'living_street', 'steps'
        ]

    # Get bounding box from place name
    south, north, west, east = __get_bbox_from_nominatim(place_name)
    highway_filter = '|'.join(highway_tags)

    # Construct Overpass QL query
    overpass_url = "http://overpass-api.de/api/interpreter"
    query = f"""
    [out:json][timeout:180];
    (
      way["highway"~"{highway_filter}"]({south},{west},{north},{east});
    );
    out geom;
    """

    # Add User-Agent and Accept headers to avoid 406 error
    headers = {
        "User-Agent": "GeoResearcher/1.0 (achituv@ariel.ac.il)",
        "Accept": "*/*",
        "Accept-Encoding": "gzip, deflate"
    }

    # Send query to Overpass API with headers
    response = requests.get(overpass_url, params={'data': query}, headers=headers, timeout=180)
    response.raise_for_status()
    data = response.json()

    # Convert results to GeoDataFrame
    roads = []
    for element in data['elements']:
        if element['type'] == 'way' and 'geometry' in element:
            coords = [(p['lon'], p['lat']) for p in element['geometry']]
            if len(coords) >= 2:
                geom = LineString(coords)
                tags = element.get('tags', {})
                tags['geometry'] = geom
                tags['osmid'] = element['id']
                roads.append(tags)

    gdf = gpd.GeoDataFrame(roads, geometry='geometry', crs='EPSG:4326')
    return gdf

gdf_osm = download_osm_roads_bbox(place)[['highway','name','osmid','junction','geometry']].to_crs(project_crs)
gdf_osm.reset_index().to_file(f"{data_folder}/osm_data.shp")

def startswith(line, sub):
    return tuple(line.coords[:len(sub.coords)]) == tuple(sub.coords)

def endswith(line, sub):
    return tuple(line.coords[-len(sub.coords):]) == tuple(sub.coords)
def merge_lines_by_attributes(gdf, attrs=['name', 'highway']):
    """
    Efficiently merges line geometries in a GeoDataFrame by grouping them based on specified attributes.

    Parameters:
        gdf (GeoDataFrame): Input GeoDataFrame with line geometries.
        attrs (list of str): List of attribute names to group by.

    Returns:
        GeoDataFrame: New GeoDataFrame with merged_inter LineStrings or MultiLineStrings split into parts.
    """
    records = []
    grouped = gdf.groupby(attrs, sort=False)

    for key, group in tqdm(grouped, total=len(grouped), desc="Merging lines"):
        lines = list(group.geometry)

        if len(lines) == 1:
            records.append({**dict(zip(attrs, key)), 'geometry': lines[0]})
            continue

        merged = linemerge(MultiLineString(lines))

        if isinstance(merged, LineString):
            records.append({**dict(zip(attrs, key)), 'geometry': merged})
        elif isinstance(merged, MultiLineString):
            for part in merged.geoms:
                records.append({**dict(zip(attrs, key)), 'geometry': part})

    return gpd.GeoDataFrame(records, crs=gdf.crs)

def trim_duplicate_line(
    inter_inter,
    merged_inter,
    tree_buffer_inter,
    edges_buffer_inter,
    idx1,
    idx2,
    buffer_distance=5
):
    """
    Lighter version:
    - Avoids gpd.overlay inside the loop
    - Uses intersection area directly on buffered overlap
    """
    subset = merged_inter.loc[[idx1, idx2]]

    # Case 1: Same name -> pick one to trim by start/end position
    if subset.loc[idx1, 'name'] == subset.loc[idx2, 'name']:
        line_to_trim_row = subset.loc[[idx2]]
        line_to_trim = line_to_trim_row['geometry'].iloc[0]

        if not (startswith(line_to_trim, inter_inter) or endswith(line_to_trim, inter_inter)):
            line_to_trim_row = subset.loc[[idx1]]
            line_to_trim = line_to_trim_row['geometry'].iloc[0]

    else:
        # Case 2: Different names -> pick the one with *smaller* overlap area
        inter_buffer = inter_inter.buffer(buffer_distance)

        # STRtree query for buffered intersection
        candidates_idx = tree_buffer_inter.query(inter_buffer)
        if len(candidates_idx) == 0:
            # fallback: arbitrarily choose idx2 to trim
            line_to_trim_row = subset.loc[[idx2]]
            line_to_trim = line_to_trim_row['geometry'].iloc[0]
        else:
            gdf_target = edges_buffer_inter.iloc[candidates_idx]

            best_name = None
            best_area = -1.0

            # Find which geometry overlaps the buffer the most
            for _, row in gdf_target.iterrows():
                area = inter_buffer.intersection(row.geometry).area
                if area > best_area:
                    best_area = area
                    best_name = row['name']

            # Trim the other line (the one that does NOT have the largest overlap)
            line_to_trim_row = subset[subset['name'] != best_name]
            if line_to_trim_row.empty:
                # fallback â€“ if logic fails, just trim idx2
                line_to_trim_row = subset.loc[[idx2]]

            line_to_trim = line_to_trim_row['geometry'].iloc[0]

    # Step: Trim based on where the overlap is
    if startswith(line_to_trim, inter_inter):
        trimmed_line = substring(line_to_trim, inter_inter.length, line_to_trim.length)
    else:
        trimmed_line = substring(line_to_trim, 0, line_to_trim.length - inter_inter.length)

    return trimmed_line, int(line_to_trim_row.index[0])


def split_lines_by_intersections_fast(gdf, intersections, snap_tol=1e-4, min_length=1e-4):
    """
    Splits line geometries at intersection points, using a spatial index
    so each line is only split by the points that actually lie on it.

    Parameters
    ----------
    gdf : GeoDataFrame
        Input lines (must have a 'geometry' column with LineString/MultiLineString).
    intersections : list[shapely.geometry.Point]
        Points where lines should be split.
    snap_tol : float, optional
        Tolerance to snap lines to points before splitting.
    min_length : float, optional
        Minimum segment length to keep (to filter tiny artefact segments).

    Returns
    -------
    GeoDataFrame
        New GeoDataFrame with split line segments, preserving all attributes.
    """

    if not intersections:
        return gdf.copy()
    # 1. Original points
    pts_points = gpd.GeoDataFrame(
        {"geometry": intersections},
        crs=gdf.crs
    )

    # 2. Copy for buffered polygons (used only for join)
    pts_poly = pts_points.copy()
    pts_poly["geometry"] = pts_poly.buffer(snap_tol)

    # 3. Spatial join using the buffered polygons
    joined = gpd.sjoin(
        pts_poly,
        gdf[["geometry"]],
        how="inner",
        predicate="intersects"
    )

    # 4. Restore point geometry in the result
    joined["geometry"] = pts_points.loc[joined.index].geometry.values

    # If no points intersect any line â€“ just return original
    if joined.empty:
        return gdf

    # joined has columns: index_left (point index), index_right (line index)
    # Group points by line index
    line_to_points = joined.groupby("index_right")["geometry"].apply(list)

    # 3) Prepare output records
    records = []

    # 3a) Handle lines that have intersection points
    for line_idx, pts in line_to_points.items():
        row = gdf.loc[line_idx]
        geom = row.geometry

        # Union only the points that intersect this specific line
        local_splitters = unary_union(pts)

        # Snap line to its own intersection points for robustness
        snapped = snap(geom, local_splitters, snap_tol)

        try:
            parts = split(snapped, local_splitters)
            for part in parts.geoms:
                if part.length > min_length:
                    attrs = row.to_dict()
                    attrs["geometry"] = part
                    records.append(attrs)
        except Exception:
            # Fallback â€“ keep original if something weird happens
            if geom.length > min_length:
                attrs = row.to_dict()
                attrs["geometry"] = geom
                records.append(attrs)

    # 3b) Handle lines that have *no* intersection points: copy them as-is
    lines_with_splits = line_to_points.index
    no_split_lines = gdf.drop(index=lines_with_splits)

    for _, row in no_split_lines.iterrows():
        geom = row.geometry
        if geom.length > min_length:
            attrs = row.to_dict()
            records.append(attrs)

    # 4) Build output GeoDataFrame
    out_gdf = gpd.GeoDataFrame(records, crs=gdf.crs)
    return out_gdf


def extend_lines_fast(lines, ext):
    """
    Vector-ish: iterate over the ndarray of shapely LineStrings (no pandas apply).
    Extends each line by `ext` at both ends along the first/last segment directions.
    Returns a Python list of LineStrings (fast to build, then wrap as GeoSeries).
    """
    out = []
    append = out.append  # local binding is a tiny speed win
    for line in lines:
        # guard: must be a LineString with >= 2 vertices

        coords = line.coords

        # start segment direction
        x0, y0 = coords[0][:2]
        x1, y1 = coords[1][:2]
        vx0, vy0 = x1 - x0, y1 - y0
        n0 = math.hypot(vx0, vy0)
        if not n0:
            append(line); continue
        sx, sy = x0 - ext * vx0 / n0, y0 - ext * vy0 / n0

        # end segment direction
        xn_1, yn_1 = coords[-2][:2]
        xn, yn     = coords[-1][:2]
        vxn, vyn   = xn - xn_1, yn - yn_1
        nn = math.hypot(vxn, vyn)
        if not nn:
            append(line); continue
        ex, ey = xn + ext * vxn / nn, yn + ext * vyn / nn

        # build once; reuse existing coords object (no list comprehensions)
        new_coords = [(sx, sy)]
        new_coords.extend((xy[0], xy[1]) for xy in coords)
        new_coords.append((ex, ey))
        append(LineString(new_coords))
    return out
def extract_internal_intersections_spatial_index_fast(
    merged,
    edges_buffer_in,
    tree_for_buffer,
    buffer_eps=0.0001,
    do_trim=True
):
    """
    Faster variant of extract_internal_intersections_spatial_index.

    Parameters
    ----------
    merged : GeoDataFrame
        Lines (e.g. road segments).
    edges_buffer_in : GeoDataFrame
        Buffered edges used inside trim_duplicate_line.
    tree_for_buffer : STRtree
        STRtree built from edges_buffer.geometry.
    buffer_eps : float
        Optional small buffer for near-miss intersections.
    do_trim : bool
        If False, skip trimming and only collect intersection points.

    Returns
    -------
    (points_list, merged_updated)
    """

    # Stable arrays: positions -> geometry, positions -> original index
    geoms = merged.geometry.to_list()
    idx_array = merged.index.to_numpy()
    tree = STRtree(geoms)

    # Collectors
    raw_points = []        # all intersection points
    seen_pairs = set()     # (min_idx, max_idx)
    to_drop = set()        # indices to drop after loop
    to_trim = dict()       # idx -> new geometry to assign

    for pos, geom in enumerate(tqdm(geoms, total=len(geoms), desc="Extracting intersections")):
        idx = idx_array[pos]

        # If this index is already marked for drop, skip
        if idx in to_drop:
            continue

        # Query spatial index for candidates
        cand_positions = tree.query(geom)
        # (if using shapely 2: tree.query(geom, predicate="intersects"))

        for c_pos in cand_positions:
            if c_pos == pos:
                continue

            jdx = idx_array[c_pos]
            if jdx in to_drop or jdx == idx:
                continue

            pair = (min(idx, jdx), max(idx, jdx))
            if pair in seen_pairs:
                continue
            seen_pairs.add(pair)

            other = geoms[c_pos]

            # If there is no intersection extend the lines by meters
            if not geom.intersects(other):
                if buffer_eps is not None and buffer_eps > 0:
                    extended = extend_lines_fast([other,geom], 1)
                    if not extended[0].intersects(extended[1]):
                        continue
                    inter_pnt = extended[0].intersection(extended[1])
                else:
                    continue
            else:
                inter_pnt = geom.intersection(other)
            if inter_pnt.is_empty:
                continue

            gtype = inter_pnt.geom_type

            # Point intersections
            if gtype == "Point":
                raw_points.append(inter_pnt)

            # Line intersections (overlaps)
            elif gtype == "LineString":
                # full overlaps â†’ mark one to drop
                if geom.equals(inter_pnt):
                    to_drop.add(idx)
                    break  # no need to continue with this geom
                if other.equals(inter_pnt):
                    to_drop.add(jdx)
                    continue

                if do_trim:
                    trimmed, id_trim = trim_duplicate_line(
                        inter_inter=inter_pnt,
                        merged_inter=merged,
                        tree_buffer_inter=tree_for_buffer,
                        edges_buffer_inter=edges_buffer_in,
                        idx1=idx,
                        idx2=jdx,
                        buffer_distance=5
                    )
                    # store trim result
                    to_trim[id_trim] = trimmed

                    # recompute a point intersection with trimmed geometry
                    if id_trim == idx:
                        new_geom = trimmed
                        inter2 = new_geom.intersection(other)
                    else:
                        new_other = trimmed
                        inter2 = geom.intersection(new_other)

                    if not inter2.is_empty:
                        if inter2.geom_type == "Point":
                            raw_points.append(inter2)
                        elif inter2.geom_type.startswith("Multi") or inter2.geom_type == "GeometryCollection":
                            raw_points.extend(
                                g for g in inter2.geoms if g.geom_type == "Point"
                            )

            # Multi/GeometryCollection â†’ take only point parts
            elif gtype.startswith("Multi") or gtype == "GeometryCollection":
                raw_points.extend(
                    g for g in inter_pnt.geoms if g.geom_type == "Point"
                )

    # ---- Apply drops and trims ----
    merged_updated = merged.drop(index=list(to_drop)).copy()

    for id_trim, new_geom in to_trim.items():
        if id_trim in merged_updated.index:
            merged_updated.at[id_trim, 'geometry'] = new_geom

    # ---- Deduplicate points by rounded coordinates ----
    unique_points = []
    seen_coords = set()

    for pt in raw_points:
        key = (round(pt.x, 6), round(pt.y, 6))
        if key not in seen_coords:
            seen_coords.add(key)
            unique_points.append(pt)

    return unique_points, merged_updated


def fix_line_topology(gdf_edges_0, is_first_time= False,org_data= False):
    """
    Cleans and fixes line topology by:
      1. Buffering edges for spatial indexing
      2. Merging lines by 'name' and 'highway'
      3. Extracting internal intersections via spatial index
      4. Splitting merged_inter lines at intersection points

    Parameters
    ----------
    gdf_edges : GeoDataFrame
        Input line layer with at least 'name' and 'highway' attributes.
    buffer_dist : float, default=1
        Buffer distance (in CRS units) used for spatial index creation.

    Returns
    -------
    fix_topology : GeoDataFrame
        Resulting GeoDataFrame of split line segments.
    internal_points : GeoDataFrame
        Points representing internal intersections.
        :param org_data:
        :param is_first_time:
    """
    buffer_dist=1
    gdf_edges_internal= gdf_edges_0.copy()
    # Step 1: Prepare buffered layer for efficient spatial indexing,
    # Initialize or reuse buffered geometries and spatial index
    if is_first_time:
        # Create buffered copy for spatial proximity queries
        edges_buffer = gdf_edges_internal.copy()
        edges_buffer["geometry"] = gdf_edges_internal.geometry.buffer(
            buffer_dist, cap_style=2
        )

        # Build spatial index on buffered geometries
        tree_buffer = STRtree(edges_buffer.geometry)
        org_data = edges_buffer, tree_buffer
    else:
        # Reuse previously computed buffer and index
        edges_buffer, tree_buffer = org_data


    # Step 2: Merge lines by 'name' and 'highway'
    gdf_merge = merge_lines_by_attributes(gdf_edges_internal, attrs=['name', 'highway'])
    gdf_merge = gdf_merge[gdf_merge.geometry.notnull()]

    # Step 3: Extract internal intersections
    internal_points_inter, merged = extract_internal_intersections_spatial_index_fast(
        gdf_merge, edges_buffer, tree_buffer
    )

    # Step 4: Split merged_inter lines at intersections
    fix_topology_fi = split_lines_by_intersections_fast(merged, internal_points_inter)
    if is_first_time:
        return fix_topology_fi, internal_points_inter,org_data
    else:
        return fix_topology_fi, internal_points_inter

def snap_endpoints(gdf: gpd.GeoDataFrame, threshold: float = 1.0):
    """
    Snap close endpoints using DBSCAN clustering.

    Parameters:
        gdf (GeoDataFrame): LineString geometries.
        threshold (float): Distance threshold for snapping points.

    Returns:
        GeoDataFrame: Updated lines with snapped endpoints.
    """

    # Step 1: Create points_data dataframe
    data = []
    for idx, geom in gdf.geometry.items():
        data.append({'line_idx': idx, 'point': Point(geom.coords[0]), 'loc': 0})
        data.append({'line_idx': idx, 'point': Point(geom.coords[-1]), 'loc': -1})

    points_data = pd.DataFrame(data)

    # Step 2: Run DBSCAN on point coordinates
    coords = np.array([[p.x, p.y] for p in points_data['point']])
    clustering = DBSCAN(eps=threshold, min_samples=2).fit(coords)
    points_data['cluster'] = clustering.labels_


    # Step 3: Filter out noise
    points_data = points_data[points_data['cluster']>-1].copy()

    # Step 4: Choose representative point for each cluster
    cluster_representatives = points_data.groupby('cluster')['point'].apply(lambda x: x.iloc[-1]).to_dict()

    # Step 5: Modify line endpoints
    gdf = gdf.copy()
    for cluster, group in points_data.groupby('cluster'):
        rep = cluster_representatives[cluster]
        for _, row in group.iterrows():
            idx = row['line_idx']
            geom = gdf.at[idx, 'geometry']
            coords = list(geom.coords)
            if row['loc'] == 0:
                coords[0] = (rep.x, rep.y)
            else:
                coords[-1] = (rep.x, rep.y)
            gdf.at[idx, 'geometry'] = LineString(coords)

    return gdf

def circular_distance(angle1, angle2):
    """Compute minimum circular angle difference between two angles."""
    diff = np.abs(angle1 - angle2) % 180
    return np.minimum(diff, 180 - diff)

def calculate_bearing(line):
    """
    Calculate the bearing (azimuth) in degrees from the start to the end of a LineString.

    Parameters:
    -----------
    line : shapely.geometry.LineString
        The input LineString geometry.

    Returns:
    --------
    float
        Bearing in degrees (0Â° to 360Â°), or NaN if the geometry is invalid or too short.
    """
    if not line or line.is_empty or len(line.coords) < 2:
        return np.nan

    x1, y1 = line.coords[0]
    x2, y2 = line.coords[-1]
    angle = np.degrees(np.arctan2(x2 - x1, y2 - y1))
    return (angle + 360) % 360
def remove_unconnected_streets(df_connected, str_name='name_left', con_str_name='name_right'):
    """
    Remove streets from a GeoDataFrame that are not connected to any other streets.

    Parameters:
    df_connected (GeoDataFrame): The input GeoDataFrame containing street data.
    str_name (str): The column name for the street name in the first dataset.
    con_str_name (str): The column name for the connected street name in the second dataset.

    Returns:
    GeoDataFrame: A new GeoDataFrame with unconnected streets removed.
    """
    df_analysis = df_connected.copy()
    s_join_analysis = gpd.sjoin(df_analysis, df_connected)
    s_join_analysis2 = s_join_analysis[s_join_analysis[str_name] != s_join_analysis[con_str_name]]
    not_connected = set(df_connected['name']) - set(s_join_analysis2.reset_index()[str_name])
    df_pro_filtered = df_connected[~df_connected['name'].isin(not_connected)]
    return df_pro_filtered

def preprocess_and_assign_roundabout_names(
    gdf_roads_0,
    buffer_distance=1.5,
):
    """
    Preprocess road geometries, detect and merge roundabouts (attribute- and geometry-based),
    and assign names to unnamed segments connected to roundabouts using topological
    connectivity and angular proximity.
    """

    # ---------------------------------------------------------------------
    # Step 0: Clean network and separate roundabout candidates
    # ---------------------------------------------------------------------

    # Remove unconnected street segments (network cleaning step)
    gdf_roads = remove_unconnected_streets(gdf_roads_0.copy())

    # --- (A) Attribute-based roundabout detection ---
    # Select roads explicitly tagged as roundabouts in OSM-like schema
    roundabout_types = ['roundabout', 'circular', 'mini_roundabout']
    mask_roundabout_attr = gdf_roads[gdf_roads['junction'].isin(roundabout_types)]

    # Remove these from main road dataset
    gdf_roads = gdf_roads[~gdf_roads['junction'].isin(roundabout_types)]

    # --- (B) Geometry-based roundabout detection ---
    # Focus only on unnamed roads (potential missing roundabout names)
    gdf_no_name = gdf_roads[
        gdf_roads['name'].isna() |
        (gdf_roads['name'].astype(str).str.strip() == "")
    ]

    # Detect highly circular closed geometries:
    # 1) Geometry must be a ring (LineString.is_ring or LinearRing)
    # 2) Circularity score C = 4Ï€A / PÂ² must exceed 0.9
    # NOTE: CRS must be projected (meters) for meaningful area/perimeter.

    def is_closed(geom):
        if geom is None or geom.is_empty:
            return False

        gt = geom.geom_type

        # Require a true geometric ring
        if gt == "LineString":
            if not geom.is_ring:
                return False
            ring = LinearRing(geom.coords)

        elif gt == "LinearRing":
            ring = geom

        else:
            return False

        # Convert ring to polygon for circularity computation
        poly = Polygon(ring)

        A = poly.area
        P = poly.length

        if A <= 0 or P <= 0:
            return False

        # Polsbyâ€“Popper circularity metric
        c = (4.0 * math.pi * A) / (P * P)

        # Strict threshold â†’ near-perfect circles only
        return c > 0.9


    # Identify geometry-based circular candidates
    mask_circular_geom = gdf_no_name.geometry.apply(is_closed)

    # Extract only circular closed geometries
    gdf_closed = gdf_no_name[mask_circular_geom]

    # Combine attribute-based and geometry-based roundabouts
    gdf_roundabouts = pd.concat(
        [mask_roundabout_attr, gdf_closed],
        ignore_index=True
    )

    # ---------------------------------------------------------------------
    # Step 1: Merge roundabout segments into continuous geometries
    # ---------------------------------------------------------------------

    # Dissolve all roundabout candidate geometries
    merged_geom = unary_union(gdf_roundabouts.geometry)

    # Merge connected line segments into longer LineStrings
    connected_lines = linemerge(merged_geom)

    # Normalize output to list of LineStrings
    if isinstance(connected_lines, LineString):
        lines_list = [connected_lines]
    elif isinstance(connected_lines, MultiLineString):
        lines_list = list(connected_lines.geoms)
    else:
        lines_list = []

    # Create GeoDataFrame of merged roundabouts
    gdf_roundabout = gpd.GeoDataFrame(
        geometry=lines_list,
        crs=gdf_roundabouts.crs
    )

    # ---------------------------------------------------------------------
    # Step 2: Buffer roundabouts to detect connected roads
    # ---------------------------------------------------------------------

    roundabout_buffer = gdf_roundabout.copy()
    roundabout_buffer['geometry'] = (
        roundabout_buffer.geometry.buffer(buffer_distance)
    )

    # ---------------------------------------------------------------------
    # Step 3: Spatial join â€” find roads intersecting roundabouts
    # ---------------------------------------------------------------------

    intersections = gpd.sjoin(
        gdf_roads,
        roundabout_buffer,
        how='inner',
        predicate='intersects'
    )

    # ---------------------------------------------------------------------
    # Step 4: Build node-based connectivity lookup
    # ---------------------------------------------------------------------

    # Create dictionary mapping node coordinate â†’ set of road indices
    # Uses start and end coordinates only (endpoint-based topology)
    node_to_osmid = {}

    for idx, row in gdf_roads.iterrows():
        geom = row.geometry
        start, end = tuple(geom.coords[0]), tuple(geom.coords[-1])

        for pt in (start, end):
            node_to_osmid.setdefault(pt, set()).add(idx)

    # ---------------------------------------------------------------------
    # Step 5: Assign names to unnamed connected roads
    # ---------------------------------------------------------------------

    for idx, row in intersections.iterrows():

        name = row['name']

        # Skip if already named
        if pd.notna(name) and name.strip() != '':
            continue

        geom = row.geometry
        start, end = tuple(geom.coords[0]), tuple(geom.coords[-1])

        # Find neighboring roads sharing endpoints
        neighbors = (
            node_to_osmid.get(start, set())
            .union(node_to_osmid.get(end, set()))
        )
        neighbors.discard(idx)  # remove self

        # Collect named neighbors with angle info
        named_neighbors = []

        for n_idx in neighbors:
            n_row = gdf_roads.loc[n_idx]
            n_name = n_row['name']

            if pd.notna(n_name) and n_name.strip() != '':
                named_neighbors.append(
                    (n_name.strip(), n_row.get('angle', 999), n_idx)
                )

        # Skip if no named neighbors
        if not named_neighbors:
            continue

        # If all neighbors share same name â†’ assign directly
        unique_names = list({n[0] for n in named_neighbors})

        if len(unique_names) == 1:
            gdf_roads.at[idx, 'name'] = unique_names[0]

        else:
            # Multiple candidate names â†’ choose by minimal angular difference
            angle_diffs = {}

            for name, angle, _ in named_neighbors:
                if name not in angle_diffs:
                    angle_diffs[name] = circular_distance(
                        angle,
                        row['angle']
                    )

            best_name = min(
                angle_diffs.items(),
                key=lambda x: x[1]
            )[0]

            gdf_roads.at[idx, 'name'] = best_name

    return gdf_roundabout, gdf_roads,gdf_no_name

gdf_roads_0= gdf_osm.copy()
gdf_roads_0['bearing'] = gdf_roads_0['geometry'].apply(calculate_bearing)
gdf_roads_0['angle'] = gdf_roads_0['bearing'].apply(lambda x: x if x < 180 else x - 180)
# Step 0: Preprocess roads and separate roundabouts
gdf_roundabout,gdf_edges,gdf_no_name = preprocess_and_assign_roundabout_names(gdf_roads_0)

# Step 1: Clean and filter edge attributes
gdf_edges = gdf_edges[
    ~gdf_edges['highway'].str.contains('link', case=False, na=False) &
    gdf_edges['name'].notna() &
    (gdf_edges['name'] != '')
]

# Step 2: Buffer for spatial indexing
fix_topology, internal_points, org_data_info = fix_line_topology(gdf_edges,True)
print ('The topology has beeen fixed')
# Step 6: Snap endpoints and compute attributes
first_results = snap_endpoints(fix_topology)
first_results['bearing'] = first_results['geometry'].apply(calculate_bearing)
first_results['angle'] = first_results['bearing'].apply(lambda x: x if x < 180 else x - 180)
first_results['length'] = first_results.length

# Step 8: Export results
first_results.reset_index().to_file(f'{data_folder}/edges.shp')


def build_street_connection_dict(gdf_streets):
    """
    Build a dictionary of street-to-street connections via unique intersection points.

    Parameters:
        gdf_streets (GeoDataFrame): A GeoDataFrame containing street segments, with a 'name' column.

    Returns:
        connection_dict (dict): A dictionary where each key is a tuple of two street names (str, str),
                                and each value is a list of unique shapely Points where the streets intersect.
    """
    # Ensure clean index
    gdf = gdf_streets.reset_index(drop=True)

    # Step 1: Perform spatial join to find intersecting features
    joined = gpd.sjoin(gdf, gdf, how='inner', predicate='intersects')
    joined = joined[joined.index != joined['index_right']]  # Remove self-intersections

    # Step 2: Initialize output containers
    connection_dict = defaultdict(list)
    seen_edges = set()

    # Step 3: Process each intersecting pair
    for idx, row in tqdm(joined.iterrows(), total=len(joined)):
        idx2 = row['index_right']
        name1 = row['name_left']
        name2 = row['name_right']

        # Skip connections within the same street
        if name1 == name2:
            continue

        pair_key = tuple(sorted((name1, name2)))
        geom1 = row.geometry
        geom2 = gdf.loc[idx2].geometry
        intersection = geom1.intersection(geom2)

        # Skip if no actual intersection
        if intersection.is_empty:
            continue

        # Normalize intersection geometry into list of points
        if intersection.geom_type == 'Point':
            inter_points = [intersection]
        elif intersection.geom_type == 'MultiPoint':
            inter_points = list(intersection.geoms)
        else:
            continue  # Ignore non-point intersections

        # Step 4: Store only new intersection points
        existing_coords = {tuple(pt.coords)[0] for pt in connection_dict[pair_key]}
        new_points = [pt for pt in inter_points if tuple(pt.coords)[0] not in existing_coords]

        if new_points:
            connection_dict[pair_key].extend(new_points)
            seen_edges.add(pair_key)

    return connection_dict
conn_dict = build_street_connection_dict(first_results)


# ------------------------------------------------------------
# STEP 2: Create a buffer around merged_inter roundabouts and find intersecting street edges
# ------------------------------------------------------------
# Buffer each merged_inter roundabout line (e.g., 5 meters)
roundabout_buffer = gdf_roundabout.copy()
roundabout_buffer['geometry'] = roundabout_buffer.geometry.buffer(5)

# Perform spatial join: find street edges that intersect the roundabout buffer
intersections = gpd.sjoin(first_results, roundabout_buffer, how='inner', predicate='intersects')

# ------------------------------------------------------------
# STEP 3: Build dictionary mapping roundabout index to connected street names
# ------------------------------------------------------------
roundabout_to_streets = defaultdict(set)
# Ensure every roundabout is included in the dictionary, even if not connected
for ridx in roundabout_buffer.index:
    roundabout_to_streets.setdefault(ridx, set())

for _, row in intersections.iterrows():
    roundabout_idx = row['index_right']  # index of the matched roundabout in gdf_merged
    street_name = row['name']
    roundabout_to_streets[roundabout_idx].add(street_name)


# ------------------------------------------------------------
# STEP 4: Calculate center point for each roundabout polygon buffer
# - Buffer again with clean style, then extract centroid
# ------------------------------------------------------------
# Buffer with styling for rounded shapes, then get centroids
roundabout_centers = gdf_roundabout['geometry'].buffer(distance=1, cap_style=1, join_style=1).centroid

# Compute distance from centroid to the boundary of the buffer
distances = [
    centroid.distance(line)
    for centroid, line in zip(roundabout_centers, gdf_roundabout['geometry'])
]

# Save as GeoDataFrame
gdf_roundabouts = gpd.GeoDataFrame(geometry=roundabout_centers, crs=gdf_roundabout.crs)
# Compute distance from centroid to buffer boundary
gdf_roundabouts['dist'] = distances
# Creata buffer of "dist" which will be used later in the code
gdf_roundabouts['geometry_buffer'] = gdf_roundabouts.apply(lambda row: row.geometry.buffer(row['dist']*2), axis=1)
gdf_roundabouts.drop(columns=['geometry_buffer']).reset_index().to_file(f'{data_folder}/center_roundabout.shp')




# This code performs the main part of the simplification
# --- Helper Functions ---

def check_parallelism(to_translate: GeoDataFrame) -> bool:
    """
    Checks whether a group of line segments contain any parallel segments
    by offsetting each line and checking buffer intersections.
    """
    my_buffer = to_translate['geometry'].buffer(cap_style=2, distance=30, join_style=3)
    to_translate['geometry_right'] = to_translate['geometry'].apply(lambda x: x.parallel_offset(35, 'right'))
    to_translate['geometry_left'] = to_translate['geometry'].apply(lambda x: x.parallel_offset(35, 'left'))

    def is_parallel(my_s_join: GeoDataFrame, the_buffer, geo_field: str):
        my_s_join = my_s_join.copy()
        my_s_join['geometry'] = my_s_join[geo_field]
        sjoin = my_s_join.sjoin(GeoDataFrame(geometry=the_buffer, crs=project_crs), how='inner')
        sjoin = sjoin[sjoin.index != sjoin['index_right']]
        for _, row in sjoin.iterrows():
            inter = row.geometry.intersection(the_buffer[row['index_right']])
            if not inter.is_empty and (inter.length / row.geometry.length) * 100 > 10:
                return True
        return False

    return is_parallel(to_translate, my_buffer, 'geometry_right') or is_parallel(to_translate, my_buffer, 'geometry_left')


def add_more_pnts_to_new_lines(pnt_f, pnt_l, line_pnts, lngth_chck, test_poly):
    """
    Recursively add points along a line if they're more than 10m from existing road segments.
    """
    dist = pnt_f.distance(pnt_l)
    x0, y0 = pnt_f.x, pnt_f.y
    bearing = math.atan2(pnt_l.x - x0, pnt_l.y - y0)
    if bearing < 0:
        bearing += 2 * math.pi
    loops = int(dist / lngth_chck)

    for step in range(1, loops):
        x_new = x0 + lngth_chck * step * math.sin(bearing)
        y_new = y0 + lngth_chck * step * math.cos(bearing)
        new_point = Point(x_new, y_new)
        nearest = GeoDataFrame(geometry=[new_point], crs=project_crs).sjoin_nearest(test_poly, distance_col='dis').iloc[0]
        if nearest['dis'] > 10:
            line = data.loc[nearest['index_right']]['geometry']
            projected = line.interpolate(line.project(new_point))
            if projected.distance(pnt_f) < 10:
                continue
            line_pnts.append(projected)
            return add_more_pnts_to_new_lines(projected, pnt_l, line_pnts, lngth_chck, test_poly)
    return line_pnts

def create_center_line(one_poly,start_end_set):
    """
    Construct a center line through a polygon by identifying its farthest endpoints
    and interpolating new points as needed based on angular continuity.
    """
    lines = data.sjoin(GeoDataFrame(geometry=[one_poly], crs=project_crs)).drop(columns='index_right')
    if lines.empty:
        # # Because of how the buffers were created, some polygons might not intersect with the original lines
        return None,start_end_set
    endpoints = []
    lines['geometry'].apply(lambda line: endpoints.extend([Point(line.coords[0]), Point(line.coords[-1])]))
    unique_points = list({
    (p.x, p.y): p
    for p in endpoints
    }.values())
    combos = list(combinations(unique_points, 2))

    df = DataFrame({
        'point_1': [a for a, _ in combos],
        'point_2': [b for _, b in combos],
    })
    df['dist'] = df.apply(lambda x: x['point_1'].distance(x['point_2']), axis=1)
    dx = df['point_2'].apply(lambda p: p.x) - df['point_1'].apply(lambda p: p.x)
    dy = df['point_2'].apply(lambda p: p.y) - df['point_1'].apply(lambda p: p.y)
    df['angle'] = np.degrees(np.arctan2(dx, dy))% 360 %180
    avg_angle = lines['angle'].mean()
    alfa =  0.7
    df['ratio'] = alfa* (df['dist'] / df['dist'].max()) +  (1- alfa) * (1 - (np.abs(df['angle'] - avg_angle) /
                   np.abs(df['angle'] - avg_angle).max()))

    pnt_f, pnt_l = df.sort_values(by='ratio', ascending=False).iloc[0][['point_1', 'point_2']]
    # In case those points are already as part of new centerline
    edge = tuple(sorted((
        (pnt_f.x, pnt_f.y),
        (pnt_l.x, pnt_l.y)
    )))
    if edge in start_end_set:
        return None, start_end_set
    start_end_set.add(edge)
    angle_range = lines['angle'].max() - lines['angle'].min()
    step = 8.5 if angle_range > 100 else 75 - log2(angle_range) * 10 if angle_range > 1 else 75
    new_line_pts = add_more_pnts_to_new_lines(pnt_f, pnt_l, [pnt_f], step, lines)
    new_line_pts.append(pnt_l)
    return new_line_pts, start_end_set

def update_df_with_center_line(new_line,highway,temp_name,is_simplified=0, group_name=-1):
    """Append a new line feature to the output dictionary."""
    dic_final['name'].append(temp_name)
    dic_final['geometry'].append(new_line)
    dic_final['highway'].append(highway)
    dic_final['group'].append(group_name)
    dic_final['is_simplified'].append(is_simplified)


# ---- usage on a GeoDataFrame of lines ----
def buffered_with_short_caps(gdf_lines: gpd.GeoDataFrame,
                             ext_m=5.0,
                             side_buffer_m=35.0,
                             ) -> gpd.GeoDataFrame:
    """
    Extends each line by `ext_m`, then buffers by `side_buffer_m` with flat caps.
    If CRS is geographic, supply a metric EPSG (e.g., 3857/2039) for correct meters.
    """
    gdfp = gdf_lines


    # 1) extend lines (fast)
    extended = extend_lines_fast(gdfp.geometry.values, ext_m)

    # 2) buffer with flat caps (vectorized in shapely 2 / geopandas)
    buffers = gpd.GeoSeries(extended, crs=gdfp.crs).buffer(side_buffer_m, cap_style=2)

    # 3) wrap as GeoDataFrame
    return gpd.GeoDataFrame(geometry=buffers, crs=gdfp.crs)

def angular_distance(a, b, period=180):
    """
    Smallest circular angular distance between a and b (degrees).
    period=180 assumes undirected line orientation (0~180).
    Use period=360 if direction matters.
    """
    diff = abs((a - b) % period)
    return min(diff, period - diff)


def pick_highway_by_length(df):
    if df["highway"].nunique() == 1:
        return df["highway"].iloc[0]
    return (
        df.assign(length=df.geometry.length)
          .groupby("highway")["length"].sum()
          .idxmax()
    )
def reassign_by_distance(group_df):
    """
    Reassigns 'group' IDs within each existing group based on spatial proximity.

    This function clusters polylines (by their centroid coordinates) within each
    original 'group' using the DBSCAN algorithm. Polylines that are spatially
    close (within the defined epsilon distance) are assigned to the same
    sub-cluster, and a new group ID is generated for each unique
    ('group', 'cluster') combination.

    Notes
    -----
    - Polylines that are not part of any cluster (label = -1) are processed
      separately via `update_df_with_center_line`.
    - The DBSCAN parameters can be adjusted (e.g., `eps`, `min_samples`)
      depending on the spatial scale of your data.
    - This function modifies 'group' and 'cluster' fields in place and returns
      only the clustered subset (`cluster` > -1).

    Parameters
    ----------
    group_df : GeoDataFrame
        Input GeoDataFrame containing at least:
        - 'geometry' : LineString geometries.
        - 'group'    : Initial group identifier.
        - 'highway'  : Used by `update_df_with_center_line` for isolated lines.

    Returns
    -------
    GeoDataFrame
        A subset of the input GeoDataFrame containing only clustered features,
        with updated 'group' values based on spatial proximity.
    """

    # Initialize cluster field
    group_df["cluster"] = -1

    # Group indices to avoid SettingWithCopy and ensure consistent assignment
    for group_id, idx in group_df.groupby("group").groups.items():
        sub_idx = list(idx)
        cents = group_df.loc[sub_idx, "geometry"].centroid
        X = np.c_[cents.x.values, cents.y.values]

        # Cluster by spatial proximity (in CRS units)
        labels = DBSCAN(eps=1000, min_samples=2).fit_predict(X)

        # Assign back to the same subset
        group_df.loc[sub_idx, "cluster"] = labels

    # Split isolated and clustered segments
    group_df_out = group_df[group_df["cluster"] == -1]
    group_df_in = group_df[group_df["cluster"] > -1]

    # Process isolated lines separately
    if len(group_df_out)>0:
        group_df_out.apply(lambda x: update_df_with_center_line(x["geometry"], x["highway"],name), axis=1)

    # Reassign new group IDs based on combined (group, cluster)
    group_df_in["group"] = group_df_in.groupby(["group", "cluster"], sort=False).ngroup()

    return group_df_in
def reassign_small_groups(
    gdf: gpd.GeoDataFrame,
    length_threshold: float = 150.0,
    max_group_size: int = 3,
    angle_col: str = "angle",
    group_col: str = "group",
    period: int = 180,
):
    """
    Iteratively:
      1) consider groups with size <= max_group_size and group != exclude_group
      2) if ANY line in that group has length > length_threshold -> keep (continue)
      3) else merge that group into another group (not exclude_group) whose average angle
         is closest to this group's average angle
      4) restart, because groups changed size

    Returns a modified copy of the GeoDataFrame.
    """
    gdf = gdf.copy()
    gdf['_len'] = gdf.length


    changed = True
    while changed:
        changed = False

        # Sizes of current groups
        sizes = gdf.groupby(group_col).size()

        # Candidate groups to check (<= max size and not excluded)
        candidates = [gid for gid, sz in sizes.items() if  sz <= max_group_size]

        if not candidates:
            break

        # Precompute average angles per group (over *all* groups)
        avg_angles = gdf.groupby(group_col)[angle_col].mean().to_dict()

        for gid in candidates:
            # Current group's rows
            mask = gdf[group_col] == gid
            grp = gdf[mask]

            # If any line is longer than the threshold â€“ do nothing for this group
            if (grp["_len"] > length_threshold).any():
                continue

            # Compute the average angle of the current group
            this_avg = avg_angles.get(gid, None)
            if this_avg is None or np.isnan(this_avg):
                continue

            # Build a list of target groups (not itself, not excluded)
            possible_targets = [tg for tg in avg_angles.keys() if tg != gid ]
            if not possible_targets:
                continue

            # Find the target with minimum angular distance
            best_tg = None
            best_dist = float("inf")
            for tg in possible_targets:
                dist = angular_distance(this_avg, avg_angles[tg], period=period)
                if dist < best_dist:
                    best_dist = dist
                    best_tg = tg

            if best_tg is None:
                continue

            # Reassign this group's members to the best target group
            gdf.loc[mask, group_col] = best_tg
            # Recompute cached values for the next loop iteration
            changed = True
            break  # restart entire while-loop after any change

    # Clean up helper column
    gdf.drop(columns=["_len"], inplace=True, errors="ignore")
    return gdf

def reassign_by_angle_adaptive(group_df, angle_col="angle", eps_tight=12, wide_thresh=80, min_samples=6):
    """
    Reassign 'group' IDs within each existing group based on angular similarity (0â€“180Â°),
    with an adaptive DBSCAN refinement for *directionally diverse* groups.

    Workflow
    --------
    For each original `group`:
    1) Compute the pairwise angular distance matrix using the undirected half-circle metric
       on [0, 180):  d(a,b)=min(|a-b|, 180-|a-b|). This bounds the maximum possible distance at 90Â°.
    2) Let `maxdiff` be the maximum pairwise angular distance within the group (range 0..90).
    3) If `maxdiff` > `wide_thresh`, the group is considered directionally heterogeneous and
       is re-clustered using DBSCAN in angular space with epsilon = `eps_tight`.
       Otherwise, all segments in the group are kept together (no angular split).

    Notes
    -----
    - This function creates/overwrites a 'cluster' column:
        * -1 indicates "noise / unassigned" (not used by the current logic, but kept for consistency
          with the distance-based version and for optional downstream handling).
        * For heterogeneous groups (`maxdiff` > `wide_thresh`), DBSCAN labels are written to 'cluster'.
          DBSCAN noise will be -1 for those groups.
        * For homogeneous groups, 'cluster' is set to the original `group_id` (i.e., one cluster).
    - Isolated/noise features (cluster == -1) are optionally forwarded to `update_df_with_center_line`.
    - Final 'group' identifiers are rebuilt using `ngroup()` over (original_group, cluster), producing
      compact consecutive IDs.

    Parameters
    ----------
    group_df : GeoDataFrame
        Input GeoDataFrame containing at least:
        - 'group' : initial group identifier
        - `angle_col` : segment orientation in degrees (expected 0â€“180; values are treated modulo 180)
        If you call `update_df_with_center_line`, the GeoDataFrame must also contain:
        - 'geometry' : LineString/MultiLineString
        - 'highway'  : road class (passed through)
    angle_col : str, default "angle"
        Name of the column holding orientation angles in degrees.
    eps_tight : float, default 12
        DBSCAN epsilon (degrees) used only for groups deemed directionally diverse
        (`maxdiff` > `wide_thresh`).
    wide_thresh : float, default 80
        Threshold (degrees) on the maximum pairwise angular distance (0..90) above which
        a group is re-clustered.
    min_samples : int, default 6
        Minimum number of segments required in a group to consider splitting. Groups smaller
        than this are left unchanged.

    Returns
    -------
    GeoDataFrame
        Subset containing only features with cluster > -1, with updated 'group' IDs.
        (Any DBSCAN noise with cluster == -1 is excluded from the returned GeoDataFrame,
        but may be processed via `update_df_with_center_line`.)
    """

    def ang_dist_180(a, b):
        """Undirected circular distance on [0,180): returns values in [0,90]."""
        d = np.abs(a - b)
        return np.minimum(d, 180 - d)

    group_df["cluster"] = -1

    # Group indices to avoid SettingWithCopy and ensure consistent assignment
    for group_id, idx in group_df.groupby("group").groups.items():
        # Skip very small groups (no splitting attempt)
        if len(idx) < min_samples:
            # Keep as one cluster (same behavior as "homogeneous")
            group_df.loc[list(idx), "cluster"] = group_id
            continue

        sub_idx = list(idx)
        ang = group_df.loc[sub_idx, angle_col].to_numpy(dtype=float) % 180.0

        # Pairwise angular distance matrix (precomputed metric for DBSCAN)
        D = ang_dist_180(ang[:, None], ang[None, :])
        maxdiff = float(D.max())  # in [0, 90]

        if maxdiff > wide_thresh:
            # Re-cluster directionally heterogeneous groups in angle space
            labels = DBSCAN(eps=eps_tight, min_samples=2, metric="precomputed").fit_predict(D)
            group_df.loc[sub_idx, "cluster"] = labels
        else:
            # Keep group intact (single angular cluster)
            group_df.loc[sub_idx, "cluster"] = group_id

    # Split isolated and clustered segments
    group_df_out = group_df[group_df["cluster"] == -1]
    group_df_in = group_df[group_df["cluster"] > -1]

    # Optional: process isolated/noise lines separately (requires `name` in outer scope)
    if len(group_df_out) > 0:
        group_df_out.apply(lambda x: update_df_with_center_line(x["geometry"], x["highway"], name), axis=1)

    # Reassign new group IDs based on combined (group, cluster)
    group_df_in["group"] = group_df_in.groupby(["group", "cluster"], sort=False).ngroup()

    return group_df_in



# --- Main logic ---
dic_final = {'name': [], 'geometry': [], 'highway': [], 'group': [], 'is_simplified': []}
df_pro = first_results.copy()
grouped = df_pro.groupby('name')
with tqdm(total=len(grouped)) as pbar:
    for name, group_df in grouped:
        strt_end_points =set() # This is for a specific case when two lines of the same street has the same start/end pnt
        pbar.update(1)
        group_df = group_df.dropna(subset=['angle'])
        if len(group_df) < 2:
            group_df.apply(lambda x: update_df_with_center_line(x['geometry'],x['highway'],name),axis=1)
            continue

        angles = group_df['angle'].to_numpy()
        angles_2d = angles[:, None]; diffs = np.abs(angles_2d - angles) % 180; dists = np.minimum(diffs, 180 - diffs).astype(float)
        dbscan = DBSCAN(eps=16, min_samples=2, metric='precomputed')
        group_df['group'] = dbscan.fit_predict(dists)

        # ------------------------------------------------------------------
        # Handle DBSCAN noise (group == -1)
        # ------------------------------------------------------------------
        # If all segments are classified as noise, forward all of them to the
        # center-line recovery routine and skip further processing for this group.
        if (group_df["group"] == -1).all():
            group_df.apply(
                lambda x: update_df_with_center_line(x["geometry"], x["highway"], name),
                axis=1
            )
            continue

        # Otherwise, process only the noise segments (group == -1) separately,
        # while keeping the remaining clustered segments for downstream steps.
        group_df_negative = group_df[group_df["group"] == -1]
        if len(group_df_negative)>0:
            group_df_negative.apply(
                lambda x: update_df_with_center_line(x["geometry"], x["highway"], name),
                axis=1
            )

        group_df = group_df[group_df['group'] >-1]
        group_df = reassign_small_groups(group_df)
        # avoid merging distant polylines into the same group
        group_df = reassign_by_distance(group_df)
        group_df = reassign_by_angle_adaptive(group_df)
        for group_id, data in group_df.groupby('group'):
            if check_parallelism(data.copy()):
                min_polylines = len(data) / 15
                condition = (data['highway'].isin(['service', 'unclassified'])) & (
                    data.groupby('highway')['highway'].transform('count') <= min_polylines)
                data = data[~condition]

                buffers = buffered_with_short_caps(data)
                unified = buffers.unary_union
                if isinstance(unified, MultiPolygon):
                    for poly in unified.geoms:
                        center_pts,strt_end_points = create_center_line(poly,strt_end_points)
                        if center_pts:
                            update_df_with_center_line(LineString(center_pts),pick_highway_by_length(data),name, 1, group_id)
                else:
                    center_pts,strt_end_points = create_center_line(unified,strt_end_points)
                    if center_pts:
                        update_df_with_center_line(LineString(center_pts),pick_highway_by_length(data),name, 1, group_id)
            else:
                data.apply(lambda x: update_df_with_center_line(x['geometry'],x['highway'], name),axis=1)


# Finalize and export
print(f'number_of_parallel: {sum(dic_final["is_simplified"])}')
print('create new files')
new_network = GeoDataFrame(dic_final, crs=project_crs)
new_network['length'] = new_network.length
new_network['bearing'] = new_network['geometry'].apply(calculate_bearing)
new_network['angle'] = new_network['bearing'].apply(lambda x: x if x < 180 else x - 180)
new_network.reset_index().to_file(f'{data_folder}/simp.shp')


# -----------------------------
# Simplify and Clean Network
# -----------------------------

def simplify_and_clean_street_network(gdf, roundabout_to_streets):
    """
    Cleans and simplifies a street network by:
    - Removing short terminal lines that are weakly connected.
    - Ensuring intersections occur at endpoints.
    - Eliminating redundant coordinates.

    Parameters:
        new_network (GeoDataFrame): The initial simplified network.
        roundabout_to_streets (dict): Mapping of roundabout IDs to connected street names.

    Returns:
        GeoDataFrame: Cleaned and simplified network.
    """


    # --------------------------------------------
    # Step 1: Precompute useful attributes
    # --------------------------------------------

    gdf['name_count'] = gdf['name'].map(gdf['name'].value_counts())

    # Count endpoint appearances across all geometries
    endpoint_counts = defaultdict(int)
    for geom in gdf.geometry:
        coords = list(geom.coords)
        endpoint_counts[coords[0]] += 1
        endpoint_counts[coords[-1]] += 1

    # --------------------------------------------
    # Step 2: Filter for lines connected to roundabouts
    # --------------------------------------------

    connected_streets = {name for names in roundabout_to_streets.values() for name in names}
    gdf_connected = gdf[gdf['name'].isin(connected_streets)].copy()


    # Flag short lines with only one connected endpoint

    candidates = gdf_connected[
        (gdf_connected.length < 100) &
        (gdf_connected['name_count'] > 1) &
        (gdf_connected.geometry.apply(lambda geom: endpoint_counts[geom.coords[0]] == 1 and
                                                      endpoint_counts[geom.coords[-1]] == 1))
    ].copy()

    # --------------------------------------------
    # Step 3: Identify short, isolated terminal lines
    # --------------------------------------------
    lines_to_remove = set(candidates[candidates.length < 30].index)


    # --------------------------------------------
    # Step 4: Find actual intersections (excluding self-intersection)
    # --------------------------------------------
    candidates = candidates[candidates.length > 30]
    intersections = gpd.sjoin(candidates, gdf, how='inner', predicate='intersects')
    intersections = intersections[intersections.index != intersections['index_right']]

    # --------------------------------------------
    # Step 5: Determine which candidates are not validly connected
    # --------------------------------------------

    for idx, row in candidates.iterrows():
        temp_line = row.geometry
        start, end = Point(temp_line.coords[0]), Point(temp_line.coords[-1])
        matching = intersections.loc[intersections.index == idx]

        if matching.empty:
            lines_to_remove.add(idx)
            continue

        # Check if intersection occurs exactly at an endpoint
        valid = False
        for other_idx in matching['index_right']:
            inter = temp_line.intersection(gdf.loc[other_idx].geometry)
            if inter.is_empty:
                continue

            # Normalize to list of points
            inter_points = [inter] if isinstance(inter, Point) else list(inter.geoms)
            if any(pt.equals(start) or pt.equals(end) for pt in inter_points):
                valid = True
                break

        if not valid:
            lines_to_remove.add(idx)

    # --------------------------------------------
    # Step 6: Remove flagged lines and clean geometry
    # --------------------------------------------

    gdf_simplified = gdf.drop(index=lines_to_remove).copy()


    # Remove duplicate consecutive points in LineString
    gdf_simplified['geometry'] = gdf_simplified['geometry'].apply(
        lambda geom: LineString([pt for pt, _ in groupby(geom.coords)]) if len(set(geom.coords)) > 1 else None
    )

    # Drop lines with invalid or null geometries
    gdf_simplified = gdf_simplified[gdf_simplified['geometry'].notnull()].copy()

    return gdf_simplified,lines_to_remove

gdf_edges= new_network.copy()
gdf_simplified,lines_to_remove = simplify_and_clean_street_network(gdf_edges, roundabout_to_streets)
# We need these lines for later process
removed_segment = gdf_edges.iloc[list(lines_to_remove)]
gdf_simplified['length'] = gdf_simplified.length
gdf_simplified.reset_index().to_file(f'{test_folder}/gdf_simplified_fix0.shp')

def choose_endpoint_if_close(new_coords, insert_idx, tolerance=30):
    """
    If the projected/nearest vertex is within `tolerance` distance
    from a segment endpoint, replace it with that endpoint.

    Parameters
    ----------
    new_coords : list of tuple
        Line coordinates [(x1,y1), (x2,y2), ...]
    insert_idx : int
        Index of the projected/nearest vertex
    tolerance : float
        Distance threshold (default=30)

    Returns
    -------
    rpt : tuple
        Chosen replacement point (possibly unchanged)
    insert_idx : int
        Updated index
    """

    def dist(p1, p2):
        return np.linalg.norm(np.array(p1) - np.array(p2))

    candidate_point = Point(new_coords[insert_idx])
    p_start =  Point(new_coords[0])
    p_end = Point(new_coords[-1])
    dist_to_start = dist(new_coords[insert_idx], new_coords[0])
    dist_to_end   = dist(new_coords[insert_idx], new_coords[-1])

    # If close to both endpoints â†’ choose closer one
    if dist_to_start < tolerance and dist_to_end < tolerance:
        if dist_to_start < dist_to_end:
            return p_start, 0
        else:
            return p_end, len(new_coords) - 1

    # If close only to start
    if dist_to_start < tolerance:
        return p_start, 0

    # If close only to end
    if dist_to_end < tolerance:
        return p_end, len(new_coords) - 1

    # Otherwise keep original
    return candidate_point, insert_idx

 # This code is enhancing the geometry of a street network by snapping street segments to nearby roundabouts to ensure cleaner, more topologically correct connections.

# --- Parameters ---
  # Threshold to treat the roundabout as coincident with a vertex

# --- Working copy ---
gdf_simplified_fix1 = gdf_simplified.copy()
existing_connections = defaultdict(list)


# compute distances from each line to the roundabout center
dists_0 = gdf_simplified_fix1.geometry.distance(roundabout_centers)
# --- Iterate roundabouts and their connected streets ---
for ridx, streets in roundabout_to_streets.items():
    roundabout_point = gdf_roundabouts.geometry.iloc[ridx]
    roundabout_dist = gdf_roundabouts['dist'].iloc[ridx]
    TOLERANCE_NEAR_VERTEX = roundabout_dist *1.5
    for street in streets:
        # Filter and drop short street edges in one step
        mask = (gdf_simplified_fix1['name'] == street) & (gdf_simplified_fix1.length < 30) & (gdf_simplified_fix1['name_count'] > 1) & (dists_0 <= roundabout_dist + 100)
        gdf_simplified_fix1 = gdf_simplified_fix1.drop(gdf_simplified_fix1[mask].index)

        # Get the remaining street edges (longer than 30)
        street_edges = gdf_simplified_fix1[(gdf_simplified_fix1['name'] == street) & (gdf_simplified_fix1.length >= 30)]

        if street_edges.empty:
            continue

        # Compute distances from each edge to the roundabout
        dists = street_edges.geometry.distance(roundabout_point)
        min_dist = dists.min()
        if min_dist > roundabout_dist + 100:
            """
            Fallback check for roundabout reconnection.

            If no remaining street segment lies within the acceptable distance
            of the roundabout, previously removed segments with the same street
            name are inspected. The closest such segment is reinstated only if
            it falls within the distance threshold.
            """

            # Check previously removed segments of the same street which are close to the curernt roundabout and at least 30 meteres
            street_edges =  removed_segment[
                (removed_segment["name"] == street) &
                (removed_segment.geometry.distance(roundabout_point) <= roundabout_dist + 100) &
                (removed_segment.length > 30)
        ]
            # Add these segments back to the database and remove them from removed_segment
            gdf_simplified_fix1 = pd.concat(
                    [gdf_simplified_fix1,  street_edges],
                    ignore_index=False
                )
            removed_segment = removed_segment.drop(index=street_edges.index)

            if street_edges.empty:
                continue

            # Compute distances to the roundabout center
            dists = street_edges.geometry.distance(roundabout_point)
            min_dist = dists.min()

            # Reinstate closest segment only if within threshold
            if min_dist > roundabout_dist + 100:
                continue

        closest_edges = street_edges[dists == min_dist].copy()

        for edge_idx, edge_row in closest_edges.iterrows():
            line = edge_row.geometry
            new_coords = list(line.coords)

            # Project the roundabout point onto the line
            nearest_pt = line.interpolate(line.project(roundabout_point))
            round_coord = roundabout_point.coords[0]

            # --- Insertion logic ---
            # Find the closest existing vertex on the line
            insert_idx = np.argmin([Point(c).distance(nearest_pt) for c in new_coords])
            # replace this index and point with the nearest end points if it is very close (less than 30 meters)
            rpt,insert_idx = choose_endpoint_if_close(new_coords, insert_idx)
            if insert_idx == 0 and roundabout_point.distance(rpt) < TOLERANCE_NEAR_VERTEX and all(not geom.contains(rpt) for geom in gdf_roundabouts.geometry.buffer(1)):
                    new_coords = [round_coord] + new_coords[1:]
            elif insert_idx == len(new_coords) - 1 and roundabout_point.distance(rpt) < TOLERANCE_NEAR_VERTEX and all(not geom.contains(rpt) for geom in gdf_roundabouts.geometry.buffer(1)):
                    new_coords = new_coords[:-1] + [round_coord]
            elif roundabout_point.distance(rpt) < TOLERANCE_NEAR_VERTEX and all(not geom.contains(rpt) for geom in gdf_roundabouts.geometry.buffer(1)):
                new_coords = new_coords[:insert_idx] + [round_coord] + new_coords[insert_idx + 1:]
            else:
                # Check angle between segments to ensure smooth connection
                def bearing(p1, p2):
                    dx, dy = p2[0] - p1[0], p2[1] - p1[1]
                    return np.degrees(np.arctan2(dy, dx)) % 360
                if insert_idx==0:
                    az1 = bearing(new_coords[insert_idx], new_coords[insert_idx +1])
                    az2 = bearing(new_coords[insert_idx], round_coord)
                else:
                    az1 = bearing(new_coords[insert_idx - 1], new_coords[insert_idx])
                    az2 = bearing(new_coords[insert_idx], round_coord)
                angle_diff = abs((az1 - az2 + 180) % 360 - 180)
                if 110 <= angle_diff <= 250:
                    new_coords = new_coords[:insert_idx] + [round_coord] + new_coords[insert_idx:]
                else:
                    new_coords = new_coords[:insert_idx + 1] + [round_coord] + new_coords[insert_idx + 1:]


            gdf_simplified_fix1.at[edge_idx,'geometry'] = LineString(new_coords)
            existing_connections[(ridx,street)].append(edge_idx)

# --- Apply updated geometries to GeoDataFrame ---
gdf_simplified_fix1.drop(columns='coords', inplace=True, errors='ignore')
gdf_simplified_fix1['length'] = gdf_simplified_fix1.length
gdf_simplified_fix1.reset_index().to_file(f'{test_folder}/gdf_simplified_fix1.shp')


def compute_azimuth(p1, p2):
    dx, dy = p2[0] - p1[0], p2[1] - p1[1]
    return np.degrees(np.arctan2(dy, dx)) % 360

def angle_difference(az1, az2):
    diff = abs(az1 - az2)
    return min(diff, 360 - diff)
def trim_roundabout_point(coords, rcoord,test_all=True,old_pnt=None):
    """
    Removes the roundabout coordinate from the coordinate list if it exists.
    This function supports cases where the roundabout is not necessarily at the start or end.
    """
    if len(coords) < 3:
        return coords
    if test_all:
        return [pt for pt in coords if pt != rcoord]
    if coords[0] == rcoord:
        coords[0] = old_pnt
        return coords
    elif coords[-1] == rcoord:
        coords[-1] = old_pnt
        return coords
    return -1



def snap_dead_ends_with_angle_filter(
    gdf_streets,
    gdf_roundabouts,
    roundabout_to_streets,
    existing_connections,
    tolerance=80
):
    gdf_fixed = gdf_streets.copy()
    node_count = defaultdict(int)

    for _, row in tqdm(gdf_fixed.iterrows(), total=len(gdf_fixed)):
        coords = list(row.geometry.coords)
        node_count[coords[0]] += 1
        node_count[coords[-1]] += 1
    for pt in gdf_roundabouts.geometry:
        node_count[pt.coords[0]] += 1

    lines_to_drop = set()

    for ridx, streets in roundabout_to_streets.items():
        roundabout_row = gdf_roundabouts.loc[ridx]
        rpt = roundabout_row.geometry
        rcoord = rpt.coords[0]
        rbuffer = roundabout_row['geometry_buffer']
        for street in streets:
            street_edges = gdf_fixed[gdf_fixed["name"] == street].copy()

            for idx, row in street_edges.iterrows():
                if idx in existing_connections[(ridx, street)]:
                    continue
                coords = list(row.geometry.coords)
                start, end = Point(coords[0]), Point(coords[-1])
                snapped = False

                if rbuffer.contains(start) and node_count[coords[0]] == 1:
                    old_pnt = coords[0]
                    coords[0] = rcoord
                    snapped = True
                elif rbuffer.contains(end) and node_count[coords[-1]] == 1:
                    old_pnt = coords[-1]
                    coords[-1] = rcoord
                    snapped = True

                if not snapped:
                    continue

                new_line = LineString(coords)
                new_is_start = coords[0] == rcoord
                new_az = compute_azimuth(rcoord, coords[1] if new_is_start else coords[-2])
                redundant = False

                for ex_id in existing_connections.get((ridx, street), []):
                    if ex_id == idx:
                        break
                    ex_geom = gdf_fixed.loc[ex_id].geometry
                    ex_coords = list(ex_geom.coords)

                    # Remove roundabout from new and existing line
                    try:
                        trimmed_new = LineString(trim_roundabout_point(coords, rcoord,False,old_pnt))
                    except:
                        pass

                    trimmed_existing =  LineString(trim_roundabout_point(ex_coords, rcoord))

                    # Distance check
                    if trimmed_new.distance(trimmed_existing) > 50:
                        existing_connections[(ridx, street)].append(idx)
                        gdf_fixed.at[idx, 'geometry'] = new_line
                        redundant = True
                    else:
                        ex_is_start = ex_coords[0] == rcoord
                        ex_az = compute_azimuth(rcoord, ex_coords[1] if ex_is_start else ex_coords[-2])
                        az_diff = angle_difference(new_az, ex_az)

                        if az_diff < tolerance:
                            if new_line.length > ex_geom.length:
                                lines_to_drop.add(ex_id)
                                existing_connections[(ridx, street)].remove(ex_id)
                                existing_connections[(ridx, street)].append(idx)
                                gdf_fixed.at[idx, 'geometry'] = new_line
                            else:
                                lines_to_drop.add(idx)
                            redundant = True
                            break

                if not redundant:
                    existing_connections[(ridx, street)].append(idx)
                    gdf_fixed.at[idx, 'geometry'] = new_line


    return gdf_fixed.drop(index=list(lines_to_drop)).copy()
gdf_simplified_fix3= snap_dead_ends_with_angle_filter(gdf_simplified_fix1,gdf_roundabouts,roundabout_to_streets,
    existing_connections)
gdf_simplified_fix3.reset_index().to_file(f'{data_folder}/gdf_fix_ra.shp')

conn_dict2 = build_street_connection_dict(gdf_simplified_fix3)

def compare_connection_dicts(original_connection_dict, updated_connection_dict):
    """
    Compare two connection dictionaries and return only the truly missing intersections.
    A point is considered missing only if it does NOT appear in the intersection lists
    of either street involved in the connection.
    """

    missing_connections = {}

    # -------------------------------------------------------
    # 1. Build street-level intersection dictionary
    #    { street : set( (x,y), ... ) }
    # -------------------------------------------------------
    street_intersections = defaultdict(set)

    for (s1, s2), pts in updated_connection_dict.items():
        for pt in pts:
            street_intersections[s1].add(tuple(pt.coords)[0])
            street_intersections[s2].add(tuple(pt.coords)[0])

    # -------------------------------------------------------
    # 2. Compare original vs. updated
    # -------------------------------------------------------
    for conn_pair, orig_points in original_connection_dict.items():
        s1, s2 = conn_pair

        # Points of the two streets from updated dictionary
        s1_pts = street_intersections.get(s1, set())
        s2_pts = street_intersections.get(s2, set())

        # Case A: Whole connection key missing
        if conn_pair not in updated_connection_dict:

            # Keep only points not found in either street
            filtered_missing = [
                pt for pt in orig_points
                if tuple(pt.coords)[0] not in s1_pts
                and tuple(pt.coords)[0] not in s2_pts
            ]

            if filtered_missing:
                missing_connections[conn_pair] = filtered_missing

        else:
            # Case B: Connection exists â†’ check point-level missing
            updated_coords = {tuple(pt.coords)[0] for pt in updated_connection_dict[conn_pair]}

            missing_pts = []
            for pt in orig_points:
                coord = tuple(pt.coords)[0]

                # Old condition: coord not in updated list
                if coord not in updated_coords:
                    # NEW condition: only if coord not found in streets either
                    if coord not in s1_pts and coord not in s2_pts:
                        missing_pts.append(pt)

            if missing_pts:
                missing_connections[conn_pair] = missing_pts

    return missing_connections
#usage
missing = compare_connection_dicts(conn_dict, conn_dict2 )

# Print or log missing entries
for pair, pts in missing.items():
    print(f"Missing connection between {pair[0]} and {pair[1]} at {len(pts)} point(s)")


# --- helpers ---------------------------------------------------------------

G = nx.Graph()
for (s1, s2), pts in missing.items():
    G.add_edge(s1, s2)
groups = []
for clique in nx.find_cliques(G):
    if len(clique) > 2:
        # All 2-combinations (pairs) inside this fully-connected set
        pairs = [tuple(sorted(p)) for p in combinations(clique, 2)]
        # (Optional) make pairs unique and sorted for stable output
        pairs = sorted(set(pairs))
        groups.append(pairs)


def _to_xy_tuple(obj):
    """Return (x, y) for a Shapely Point or an (x, y) tuple."""
    if isinstance(obj, Point):
        return (obj.x, obj.y)
    return tuple(obj)

def build_roundabout_index(gdf_roundabouts, tol=1e-6):
    """
    Precompute a quantized coordinate set for roundabout points for O(1) lookups.
    Use the same tol you'll use in is_roundabout_coord().
    """
    return {
        (round(pt.x / tol), round(pt.y / tol))
        for pt in gdf_roundabouts.geometry
    }

def is_roundabout_coord(coord_xy, round_idx, tol=1e-6):
    """Check if coord_xy (x,y) coincides with a roundabout point (within tol)."""
    qx = round(coord_xy[0] / tol)
    qy = round(coord_xy[1] / tol)
    return (qx, qy) in round_idx
# --------------------------------------------------------------------------

def filter_intersection_points(points, tolerance=80):
    """
    Filters a list of intersection points based on spatial proximity.

    Logic:
    - If only 1 or 0 points: return as-is with empty representative mapping.
    - If 2 points: if close (< tolerance), return one and map both to it.
    - If >2: use DBSCAN to group points, select one per group, and store mapping from all grouped points to representative.

    Ensures the representative point is not duplicated in its own value list.

    Parameters:
        points (list of shapely.geometry.Point)
        tolerance (float): distance threshold in meters for clustering

    Returns:
        tuple:
            - list of representative points (filtered)
            - dict: {representative Point: [all merged_inter Point(s) excluding rep]}
    """
    if len(points) <= 1:
        return points, {}

    if len(points) == 2:
        if points[0].distance(points[1]) < tolerance:
            return [points[0]], {points[0]: [points[1]]}
        else:
            return points, {}

    # More than two points â†’ use DBSCAN
    coords = np.array([[pt.x, pt.y] for pt in points])
    db = DBSCAN(eps=tolerance - 10, min_samples=1).fit(coords)
    labels = db.labels_

    result = []
    group_map = defaultdict(list)

    label_to_rep = {}
    for label in np.unique(labels):
        rep_idx = np.where(labels == label)[0][0]
        rep = points[rep_idx]
        label_to_rep[label] = rep
        result.append(rep)

    for pt, label in zip(points, labels):
        rep = label_to_rep[label]
        if pt != rep:
            group_map[rep].append(pt)

    return result, group_map

class ConnectivityRepair:
    def __init__(self,current_god, removed_segment_gpd):
        self.gdf_streets = current_god.copy()
        self.removed_segment = removed_segment_gpd
    def find_nearest_line(self,lines_geo, point: Point, max_dist=500):
        # We first check if the nearset one is nearby
        def best_row(lines_geo, point: Point):
            # Here we calcualte the nearest one
            return lines_geo.loc[[lines_geo.geometry.distance(point).idxmin()]]

        line_name = lines_geo.iloc[0]['name']
        bst_rw = best_row(lines_geo, point)
        # 1) Normal case: nearest in current set is close enough
        if (bst_rw.geometry.distance(point) <= max_dist).any():
            return bst_rw

        # 2) Fallback: try to restore from previously removed segments (same name, length > 30m)
        cand = self.removed_segment[
            (self.removed_segment["name"] == line_name) &
            (self.removed_segment.geometry.length > 30)
        ].copy()

        bst_rw = best_row(cand, point)
        # add it back to current streets, remove it from removed_segment
        self.gdf_streets = pd.concat([self.gdf_streets, bst_rw ], ignore_index=False)
        self.removed_segment = self.removed_segment.drop(index=bst_rw.index)
        return bst_rw



test= ConnectivityRepair(gdf_simplified_fix3,removed_segment)

test.gdf_streets['has_changed']= 0
streets_to_skip=[]

# distance threshold in meters
MAX_SNAP_DIST = 500
ROUND_TOL = 1e-6
round_idx = build_roundabout_index(gdf_roundabouts, tol=ROUND_TOL)

for grp_idx, my_complex in enumerate(tqdm(groups, total=len(groups))):
    str_points = {}
    for str_tuple in my_complex:
        points_0 = missing[str_tuple]
        points, points_map = filter_intersection_points(points_0)
        str_points[str_tuple] = points

    # Flatten once (vectorized-ish)
    min_samples = 2
    eps = 30
    # Build rows in a single pass
    rows = [(s1, s2, pt.x, pt.y, pt)
            for (s1, s2), pts in str_points.items()
            for pt in pts]

    df = pd.DataFrame(rows, columns=["street1", "street2", "x", "y", 'geometry'])

    # Coordinates for clustering
    X = df[["x", "y"]].to_numpy(dtype=float)

    # Run DBSCAN
    labels = DBSCAN(eps=eps, min_samples=min_samples, metric="euclidean").fit(X).labels_

    # Attach labels
    df["label"] = labels
    # Filter out noise (-1 labels)
    df_filtered_0 = df[df["label"] != -1].copy()
    for _, df_filtered in df_filtered_0.groupby('label'):
        # Count frequency of each unique (x, y) coordinate
        freq = (
            df_filtered.groupby(["x", "y"])
            .size()
            .reset_index(name="freq")
        )
        # Merge frequency back into original DataFrame
        df = df_filtered.merge(freq, on=["x", "y"], how="left")


        if df_filtered.empty:
            continue
        else:
            streets_to_skip.extend(zip(df['street1'], df['street2'])) # streets pair to skip for the next step
            unique_streets = pd.unique(df[["street1", "street2"]].values.ravel())
            df_sorted = df[df["freq"] == df["freq"].max()]
            point_to_update = df_sorted.iloc[0].geometry
            point_to_update_to_add = point_to_update.coords[0]
            for street in unique_streets:
                lines = test.gdf_streets[test.gdf_streets['name'] == street].copy()
                nearest_line_all = test.find_nearest_line(lines, point_to_update)
                if len(nearest_line_all)==1:
                    nearest_line = nearest_line_all['geometry'].iloc[0]
                else:
                    nearest_line = nearest_line_all['geometry']
                if len(df_sorted)>1:
                    df_sorted["dist"] = df_sorted["geometry"].apply(lambda g: g.distance(nearest_line))
                    point_to_update = df_sorted.loc[df_sorted["dist"].idxmin(), "geometry"]
                    point_to_update_to_add = point_to_update.coords[0]
                coords = list(nearest_line.coords)
                d = nearest_line.project(point_to_update)
                projected = nearest_line.interpolate(d)
                insert_idx = np.argmin([Point(c).distance(projected) for c in coords])
                _,insert_idx = choose_endpoint_if_close(coords, insert_idx)
                # ... inside your processing block (where you have coords, insert_idx, point_to_update_to_add):
                curr_xy = _to_xy_tuple(coords[insert_idx])           # coords is a list of (x,y) from geom.coords
                # Guard: if this index is a roundabout point, do nothing
                if not is_roundabout_coord(curr_xy, round_idx, tol=ROUND_TOL):
                    if insert_idx == 0:
                        if Point(coords[0]).distance(point_to_update) < 40:
                            coords = [point_to_update_to_add] + coords[1:]
                        else:
                            coords = [coords[0]] + [point_to_update_to_add] + coords[1:]
                    elif insert_idx == len(coords) - 1:
                        if Point(coords[-1]).distance(point_to_update) < 40:
                            coords = coords[:-1] + [point_to_update_to_add]
                        else:
                            coords = coords[:-1] + [point_to_update_to_add] + [coords[-1]]
                    else:
                        for i in range(len(coords) - 1):
                            seg_start = Point(coords[i])
                            seg_end = Point(coords[i + 1])
                            seg_line = LineString([seg_start, seg_end])

                            # check if the projected point lies on this segment
                            if seg_line.distance(projected) < 1e-8:  # numerical tolerance
                                if coords[i] == 0 or Point(coords[i]).distance(point_to_update) > 100:
                                    coords_0 = coords[:i + 1] + [point_to_update_to_add]
                                else:
                                    coords_0 = coords[:i] + [point_to_update]
                                if coords[i + 1] == len(coords) - 1 or Point(coords[i + 1]).distance(point_to_update) > 100:
                                    coords = coords_0 + coords[i + 1:]
                                else:

                                    coords = coords_0 + coords[i + 2:]
                                break
                test.gdf_streets.at[nearest_line_all.index.item(), 'geometry'] = LineString(coords)
                test.gdf_streets.at[nearest_line_all.index.item(),'has_changed']= 2
test.gdf_streets.reset_index().to_file(f'{test_folder}/complex_sit.shp')

def find_nearest_intersections_overlay(gdf1, gdf2, ref_pnt):
    """
    Vectorized approach: find the minimum distance from each gdf1 line to the nearest intersection
    with lines in gdf2, measured from a reference point on each gdf1 line.

    Parameters:
        gdf1 (GeoDataFrame): GeoDataFrame with LineString geometries.
        gdf2 (GeoDataFrame): Another GeoDataFrame with LineString geometries.
        ref (str): Reference point on gdf1 geometry. Options: 'centroid', 'start', or 'end'.

    Returns:
        list of float: Distances from each gdf1 feature to its nearest intersection point, or 35 if no intersection.
        :param ref_pnt:
    """

    gdf1['geometry'] = gdf1['geometry'].buffer(0.1)
    gdf2['geometry'] = gdf2['geometry'].buffer(0.1)
    intersections = gpd.overlay(gdf1, gdf2, how='intersection')

    if intersections.empty:
        return 35
    # Map reference points to intersections
    # Compute distance to a given point (pt_coords should be a shapely.geometry.Point)
    intersections['distance'] = intersections.geometry.distance(ref_pnt)
    return intersections['distance'].min()

def extend_line_to_target(line: LineString, endpoint_index: int, target: LineString) -> LineString:
    """
    Extend a line by projecting its start or end point onto a target line.

    Parameters:
        line (LineString): The line to extend.
        endpoint_index (int): Use 0 to extend from start, -1 from end.
        target (LineString): The line to project the endpoint onto.

    Returns:
        LineString: Extended line.
    """
    coords = list(line.coords)

    if len(coords) < 2:
        return line  # Can't extend a single-point line

    # Get reference segment
    if endpoint_index == 0:
        p2 = Point(coords[0])
    else:
        p2 = Point(coords[-1])

    # Get projected point from p2 to target
    proj_distance = target.project(p2)
    projected_point = target.interpolate(proj_distance)

    # Extend line to this projected point
    if endpoint_index == 0:
        new_coords = [projected_point.coords[0]] + coords
    else:
        new_coords = coords + [projected_point.coords[0]]

    return LineString(new_coords)

def get_closest_endpoint_to_line(line_a: LineString, line_b: LineString):
    """Returns the endpoint of line_a closest to line_b and its distance."""
    endpoints = [Point(line_a.coords[0]), Point(line_a.coords[-1])]
    distances = [pt.distance(line_b) for pt in endpoints]
    return np.argmin(distances), distances[np.argmin(distances)]


def connect_lines(line1, line2):
    """
    Returns a modified line1 or line2 extended to intersect with the other.
    """
    lg1 = line1.geometry.iloc[0]
    lg2 = line2.geometry.iloc[0]
    idx1, dist1 = get_closest_endpoint_to_line(lg1, lg2)
    idx2, dist2 = get_closest_endpoint_to_line(lg2, lg1)

    if dist1 < dist2:
        return extend_line_to_target(lg1, idx1, lg2), line1.index[0]
    else:
        return extend_line_to_target(lg2, idx2, lg1), line2.index[0]


class Pairwise(ConnectivityRepair):
    """
    Class for simplifying and cleaning road network geometries.
    Contains methods for handling roundabouts, intersections, and street connections.
    """

    def __init__(self,current_god, removed_segment_gpd,tolerance_nearest=30):
        """
        Initialize with a GeoDataFrame containing road network data.

        Parameters:
            current_god (GeoDataFrame): Input road network data to be copied.
            removed_segment_gpd (GeoDataFrame): Removed segment data.
            tolerance_nearest (int, optional): Tolerance distance for nearest point calculations. Default is 30.
        """
        super().__init__(current_god, removed_segment_gpd)
        self.tolerance_nearest = tolerance_nearest

    def snap_missing_points_to_streets(self, missing):
        for (street1, street2), points_0 in tqdm(missing.items(), total=len(missing)):
            if (street1, street2) in streets_to_skip:
                continue
            points, points_map = filter_intersection_points(points_0)
            lines1 = self.gdf_streets[self.gdf_streets['name'] == street1].copy()
            lines2 = self.gdf_streets[self.gdf_streets['name'] == street2].copy()
            if len(points)==1:
                if len(lines1.sjoin(lines2))>0:
                    continue
                else:
                    self.connect_nearest_lines(lines1, lines2, points[0])
            else:
                for pt in points:
                    if find_nearest_intersections_overlay(lines1.copy(),lines2.copy(),pt) < self.tolerance_nearest:
                        continue
                    else:
                        self.connect_nearest_lines(lines1.copy(), lines2.copy(), pt)

    def connect_nearest_lines(self,lines1, lines2, point):
        """
        Finds the nearest line in each set to a given point, connects them using a custom function,
        and updates the geometry in gdf_streets.

        Parameters:
            lines1 (GeoDataFrame): First set of candidate lines (subset of gdf_streets).
            lines2 (GeoDataFrame): Second set of candidate lines (subset of gdf_streets).
            point (shapely.geometry.Point): The reference point to determine nearest lines.
            connect_lines_func (function): A function that takes two lines and returns (new_line, index_to_update).

        Returns:
            GeoDataFrame: Updated gdf_streets with the new connected line geometry.
        """

        line1 = self.find_nearest_line(lines1, point)
        line2 = self.find_nearest_line(lines2, point)
        new_line, new_idx = connect_lines(line1, line2)
        self.gdf_streets.at[new_idx, 'geometry'] = new_line
        self.gdf_streets.at[new_idx, 'has_changed'] =1

# Main loop
gdf_fixed  =  Pairwise(test.gdf_streets, removed_segment)
gdf_fixed.snap_missing_points_to_streets(missing)
# Step 2: Buffer for spatial indexing
mid_result, internal_points= fix_line_topology(gdf_fixed.gdf_streets,False,org_data=org_data_info)
mid_result.reset_index().to_file(f'{data_folder}/network_final.shp')

def extract_deadend_points(gdf_edges):
    """
    Identifies all dead-end points (start or end points that appear only once in the entire edge dataset).

    Parameters:
        gdf_edges (GeoDataFrame): Edge lines with LineString geometries.

    Returns:
        Set of Points: All dead-end points.
    """
    endpoint_counter = defaultdict(int)
    # def round_point(pt, ndigits=2):
    #     return tuple(round(c, ndigits) for c in pt)

    for geom in gdf_edges.geometry:
        coords = list(geom.coords)
        endpoint_counter[coords[0]] += 1
        endpoint_counter[coords[-1]] += 1

    return endpoint_counter

def _extend_to_target(pt_deadend: Point,
                      pt_prev: Point,
                      gdf_all: gpd.GeoDataFrame,
                      sindex,
                      cidx,
                      max_length: float = 100,
                      edges_union=None):
    """
    Extend a one-sided dead-end toward nearby network geometry.

    A ray is emitted from the dead-end endpoint in the direction defined by the adjacent
    vertex -> dead-end endpoint. If the ray intersects any other edge, the nearest
    intersection point (to the dead end) is returned. Otherwise, the dead end is
    projected to the nearest edge (fallback).

    Parameters
    ----------
    pt_deadend : shapely.geometry.Point
        Dead-end endpoint to extend from.
    pt_prev : shapely.geometry.Point
        Vertex adjacent to the dead-end endpoint; defines the local heading direction.
    gdf_all : geopandas.GeoDataFrame
        Full edge set used as potential extension targets.
    sindex : geopandas.sindex.SpatialIndex
        Spatial index for gdf_all; used to prefilter candidates.
    cidx : hashable
        Index of the current edge in gdf_all to exclude self-intersections.
    max_length : float, default=100
        Maximum ray length (in CRS units, typically meters).

    Returns
    -------
    (shapely.geometry.Point, int)
        A tuple of (target_point, case_code), where case_code indicates how the target was
        obtained:
          4 = ray intersection with another edge
          5 = projection to nearest edge (fallback)

    Notes
    -----
    If the direction vector is degenerate (zero length), the dead-end point is returned.
    """

    vec = np.array(pt_deadend.coords[0]) - np.array(pt_prev.coords[0])
    norm = np.linalg.norm(vec)
    if norm == 0:
        return pt_deadend # degenerate direction; treat as fallback-like behavior
    vec_unit = vec / norm

    ray_end = Point(pt_deadend.x + vec_unit[0] * max_length,
                    pt_deadend.y + vec_unit[1] * max_length)
    ray = LineString([pt_deadend, ray_end])

   # Candidate filtering via spatial index
    hits = list(sindex.intersection(ray.bounds))
    candidates0 = gdf_all.iloc[hits]
    candidates = candidates0[candidates0.index != cidx].geometry

    # Ray intersection (if any)
    intersection_pts = [ray.intersection(g) for g in candidates if ray.intersects(g)]
    intersection_pts = [pt for pt in intersection_pts if not pt.is_empty]
    if intersection_pts:
        # Pick the closest intersection to the dead-end
        dists = [pt_deadend.distance(pt) for pt in intersection_pts]
        return intersection_pts[int(np.argmin(dists))],4
    else:
        # Fallback: project to nearest edge (union precomputed outside loop for speed)
        if edges_union is None:
            edges_union = gdf_all.drop(cidx).geometry.unary_union
        proj = nearest_points(pt_deadend, edges_union)[1]
        return proj, 5


def keep_shortest_same_endpoints(
    gdf: gpd.GeoDataFrame,
    max_keep_length: float = 200  # meters
) -> gpd.GeoDataFrame:
    g = gdf.copy()

    # Extract start/end coordinates
    start_xy = g.geometry.apply(lambda geom: geom.coords[0])
    end_xy   = g.geometry.apply(lambda geom: geom.coords[-1])

    # Undirected key: (A,B) == (B,A)
    g["_group_key"] = [
        (a, b) if a <= b else (b, a)
        for a, b in zip(start_xy.to_list(), end_xy.to_list())
    ]

    # Split by length condition
    long_lines  = g[g["length"] > max_keep_length].copy()
    short_lines = g[g["length"] <= max_keep_length].copy()

    # From short lines: keep shortest per group
    keep_idx_short = short_lines.groupby("_group_key")["length"].idxmin()
    kept_short = short_lines.loc[keep_idx_short]

    # Combine: always keep long lines + filtered short ones
    kept = gpd.GeoDataFrame(
        pd.concat([long_lines, kept_short], ignore_index=True),
        crs=gdf.crs
    )
    return kept.drop(columns=["_group_key"], errors="ignore").reset_index(drop=True)

def clean_and_fix_deadends(
        buffer_union_temp,
        edges_to_fix: gpd.GeoDataFrame,
        preserved_old: set,
        preserved_new: set,

        *,
        buffer_close: float = 15,
        short_cut: float = 50,
) -> gpd.GeoDataFrame:
    """
    Clean and repair dead-ends in a street-edge GeoDataFrame.

    This routine removes isolated artifacts (e.g., short spurious stubs) while preserving
    legitimate termini (e.g., cul-de-sacs) and repairing plausible missing connections by
    extending one-sided dead ends toward nearby network geometry.

    The method operates on an *updated* edge set (edges_to_fix) while using two endpoint
    reference sets:
      - preserved_new: endpoints currently classified as dead ends in the updated network
      - preserved_old: endpoints classified as dead ends in the original network (used as an
        anchoring reference to avoid deleting true termini that were slightly displaced)

    Dead-end logic is applied per edge using endpoint membership in preserved_new, and a
    hierarchical decision rule is used to keep, drop, or extend candidate edges.

    Parameters
    ----------
    edges_to_fix : geopandas.GeoDataFrame
        LineString edges to process. Must contain a valid geometry column (LineString) and
        be in a projected CRS where distance units are meters (or consistent with thresholds).
    preserved_old : set
        Set of original-network dead-end endpoint coordinates or Points (iterable compatible
        with `Point(old)` in the distance check). Used to preserve true termini.
    preserved_new : set
        Set of updated-network dead-end endpoint coordinates (must match `g.coords[0]` /
        `g.coords[-1]` types). Used to label dead-end endpoints in the current network.
    buffer_close : float, default=15
        Distance threshold (meters) for preserving a dead-end endpoint if it is close to any
        original preserved dead-end location.
    short_cut : float, default=50
        Length threshold (meters) below which a one-sided dead-end edge is treated as a short
        stub and removed.
    extend_max : float, default=150
        Maximum extension length (meters) when repairing a one-sided dead end.

    Returns
    -------
    geopandas.GeoDataFrame
        A cleaned GeoDataFrame consisting of:
          - all edges without dead ends (kept unchanged),
          - preserved one-sided dead ends (kept unchanged),
          - extended one-sided dead ends (geometry modified),
        while dropping (i) edges dead-ending at both ends and (ii) short one-sided stubs.

    Notes
    -----
    The function also writes a diagnostic shapefile (`fix_rows.shp`) containing the subset
    of edges that were evaluated as dead-end candidates. A 'case' attribute is populated
    for traceability:
      1 = dropped (dead-end at both ends)
      2 = kept (near original preserved dead end)
      3 = dropped (short stub)
      4 = extended to first ray intersection with another edge
      5 = extended by projection to nearest edge (fallback)

    Requirements / assumptions
    --------------------------
    - edges_to_fix geometries are LineStrings with at least two vertices.
    - Distance-based parameters assume a projected CRS in meters.
    - Uses GeoPandas spatial index for candidate filtering in extension step.
    :param gdf_no_name_poly_temp:
    """
    # --- 1. Annotate dead-end status ----------------------------------------
    def _is_deadend(pt):
        return pt in preserved_new

    sindex = edges_to_fix.sindex
    edges_to_fix["start_deadend"] = edges_to_fix.geometry.apply(lambda g: _is_deadend(g.coords[0]))
    edges_to_fix["end_deadend"]   = edges_to_fix.geometry.apply(lambda g: _is_deadend(g.coords[-1]))
    edges_to_fix["has_deadend"]   = edges_to_fix["start_deadend"] | edges_to_fix["end_deadend"]

    # Split: rows with / without dead-ends
    keep_rows = edges_to_fix[~edges_to_fix.has_deadend].copy()
    fix_rows  = edges_to_fix[edges_to_fix.has_deadend].copy()


    deadend_records = []

    for idx, row in fix_rows.iterrows():
        geom = row.geometry
        coords = list(geom.coords)

        if row["start_deadend"]:
            deadend_records.append({
                "line_id": idx,
                "position": "start",
                "geometry": Point(coords[0])
            })

        if row["end_deadend"]:
            deadend_records.append({
                "line_id": idx,
                "position": "end",
                "geometry": Point(coords[-1])
            })

    deadend_points_gdf = gpd.GeoDataFrame(deadend_records, crs=fix_rows.crs)
    # extract x,y coordinates
    coords = np.array([(geom.x, geom.y) for geom in deadend_points_gdf.geometry])

    # run DBSCAN with 15 meter tolerance
    db = DBSCAN(eps=15, min_samples=2)
    deadend_points_gdf["cluster"] = db.fit_predict(coords)

    deadend_points_close  =  deadend_points_gdf[deadend_points_gdf['cluster']>-1]

    # group info per cluster
    cluster_info = (
        deadend_points_close
        .groupby("cluster")
        .agg(
            n_points=("line_id", "size"),
            n_unique_lines=("line_id", "nunique")
        )
    )

    clusters_to_remove = cluster_info[
    (cluster_info["n_points"] == 2) &
    (cluster_info["n_unique_lines"] == 1)
].index

    # filter them out
    deadend_points_close = deadend_points_close[
        ~deadend_points_close["cluster"].isin(clusters_to_remove)
    ]

    def connect_deadend_pair(row1,row2):


            line_id_1 = row1["line_id"]   # line to extend
            line_id_2 = row2["line_id"]   # line to only update flags


            pt2 = row2.geometry
            pos1 = row1["position"]
            pos2 = row2["position"]

            # -------------------------------
            # Update geometry of line 1 only
            # -------------------------------
            geom1 = fix_rows.at[line_id_1, "geometry"]
            coords1 = list(geom1.coords)

            if pos1 == "start":
                new_coords1 = [(pt2.x, pt2.y), *coords1]
                fix_rows.at[line_id_1, "start_deadend"] = False
            else:  # end
                new_coords1 = [*coords1, (pt2.x, pt2.y)]
                fix_rows.at[line_id_1, "end_deadend"] = False

            fix_rows.at[line_id_1, "geometry"] = LineString(new_coords1)

            # -----------------------------------------
            # Update dead-end flag of line 2 only
            # -----------------------------------------
            if pos2 == "start":
                fix_rows.at[line_id_2, "start_deadend"] = False
            else:  # end
                fix_rows.at[line_id_2, "end_deadend"] = False

            # -----------------------------------------
            # Move rows that no longer have dead-ends
            # -----------------------------------------
            if (not fix_rows.at[line_id_1, "start_deadend"]) and (not fix_rows.at[line_id_1, "end_deadend"]):
                rows_to_move.add(line_id_1)

            if (not fix_rows.at[line_id_2, "start_deadend"]) and (not fix_rows.at[line_id_2, "end_deadend"]):
                rows_to_move.add(line_id_2)

    rows_to_move = set()

    for _, group in deadend_points_close.groupby("cluster", sort=False):
        if len(group) == 2:
            connect_deadend_pair(group.iloc[0], group.iloc[1])
        else:
            group['used'] = 0
            for _, row in group.iterrows():
                # skip if this point already used in a connection
                if row['used']>0:
                    continue
                else:
                    pt1 = row.geometry
                    line_id_1 = row["line_id"]
                     # build candidate table from other points in same cluster
                    candidates = group[(group['line_id'] != line_id_1) & (group['used'] != 1)]
                    if len(candidates)==0:
                        continue
                    candidates["dist"] = candidates.geometry.distance(pt1)
                    candidates = candidates.sort_values("dist")
                    for idx2, row2 in candidates.iterrows():
                        # since sorted, can stop immediately
                        if row2['dist'] > buffer_close:
                            break
                         # valid pair -> connect
                        connect_deadend_pair(row, row2)
                        # mark both points as used
                        # that is signify that more points ban be connected to it but it is not a deadend anymore
                        row2[ "used"] = 2
                        break
                    row["used"] = 1

    # Move completed rows once, after loop
    if rows_to_move:
        rows_to_move = list(rows_to_move)
        keep_rows = pd.concat([keep_rows, fix_rows.loc[rows_to_move]])
        fix_rows = fix_rows.drop(index=rows_to_move)

    # --- Create STRtree spatial index directly from deadend points ---
    fix_rows['case'] = 1000
    fixed_geoms = []
    # Precompute once — avoids rebuilding unary_union on every fallback call
    all_edges_union = edges_to_fix.geometry.unary_union
    # Build spatial index once
    point_objects = [Point(coord) for coord in preserved_old]
    tree_old = STRtree(point_objects)
    for idx, row in tqdm(fix_rows.iterrows(), total=len(fix_rows), desc="Processing edges"):

        geom = row.geometry
        coords = list(geom.coords)
        start_pt, end_pt = Point(coords[0]), Point(coords[-1])
        start_de, end_de = row.start_deadend, row.end_deadend

        # --- 2. Remove if dead-end at both ends -----------------------------
        if start_de and end_de:
            fix_rows.loc[idx, 'case'] = 1
            continue  # DROP edge entirely

        # Identify the dead-end endpoint and its adjacent (previous) vertex.
        if start_de:
            de_pt, prev_pt = start_pt, Point(coords[1])
            if de_pt==prev_pt:
                prev_pt = Point(coords[2])
        else:
            de_pt, prev_pt = end_pt, Point(coords[-2])
            if de_pt==prev_pt:
                prev_pt = Point(coords[-3])


        # --- 3. Preserve if close to an original dead end -------------------


        # Query for points within buffer
        candidates = tree_old.query(de_pt.buffer(buffer_close))
        is_no_name = buffer_union_temp.contains(de_pt)> 0
        if len(candidates) and  not is_no_name:
            fixed_geoms.append(row)  # keep as-is
            fix_rows.loc[idx, 'case'] = 2
            continue

        # --- 4. Drop short one-sided stubs ----------------------------------
        if geom.length < short_cut:
            fix_rows.loc[idx, 'case'] = 3
            continue  # DROP

        # --- 5. Extend remaining one-sided dead ends ------------------------
        extend_max = 100 if is_no_name else 150 # in case of connection ot streets without name we extend the maximum range
        new_pt, case = _extend_to_target(de_pt, prev_pt, edges_to_fix, sindex, idx, max_length=extend_max, edges_union=all_edges_union)

        fix_rows.loc[idx, 'case'] = case
        # If extension failed or did not return a usable point, skip.
        if isinstance(new_pt, MultiPoint):
            new_pt = new_pt.geoms[0]
        if  new_pt is None or new_pt.geom_type not in ["Point","MultiPoint"]:
            print("\nâŒ Extension failed / non-Point returned")
            print(f"idx: {idx}")
            print(f"returned new_pt type: {None if new_pt is None else new_pt.geom_type}")
            print(f"returned new_pt wkt: {None if new_pt is None else new_pt.wkt}")
            continue
        # Build the updated LineString by replacing the dead-end endpoint.
        if start_de:
            new_coords = [(new_pt.x, new_pt.y),*coords]
        else:
            new_coords = [*coords,(new_pt.x, new_pt.y)]
        row['geometry'] = LineString(new_coords)
        fixed_geoms.append(row)

    # Combine kept originals + processed fixes
    gdf_out = GeoDataFrame(fixed_geoms, crs=edges_to_fix.crs)
    # Diagnostic export of processed candidate edges (optional side-effect)
    fix_rows.reset_index().to_file(f'{test_folder}/fix_rows.shp')
    return gpd.GeoDataFrame(pd.concat([keep_rows, gdf_out]), crs=project_crs)





# preserved_* are sets of shapely Points
preserved_deadends_old = {
    pt for pt, val in extract_deadend_points(first_results).items() if val == 1
}
preserved_deadends_new = {
    pt for pt, val in extract_deadend_points(mid_result).items() if val == 1
}

# Create buffer around gdf_no_name
gdf_no_name_poly = GeoDataFrame(
    geometry=gdf_no_name['geometry'].buffer(distance=10, cap_style=1),
    crs=project_crs
)
# Union all buffers into a single geometry for faster testing
buffer_union = gdf_no_name_poly.geometry.unary_union


mid_result2 = mid_result.copy().set_geometry("geometry")

clean_edges = clean_and_fix_deadends(
    buffer_union,
    mid_result2,
    preserved_old=preserved_deadends_old,
    preserved_new=preserved_deadends_new,
)

# Step 3: Split merged_inter lines by these points
mid_result3,internal_points= fix_line_topology(clean_edges,False,org_data=org_data_info)

# preserved_* are sets of shapely Points
preserved_deadends_new = {
    pt for pt, val in extract_deadend_points(mid_result3).items() if val == 1
}

clean_edges = clean_and_fix_deadends(
    buffer_union,
    mid_result3,
    preserved_old=preserved_deadends_old,
    preserved_new=preserved_deadends_new
)

# Step 3: Split merged_inter lines by these points
final_result_0,internal_points= fix_line_topology(clean_edges,False,org_data=org_data_info)


final_result_0['length'] = final_result_0.length
# The code remove segments with the same start/end points
final_result = keep_shortest_same_endpoints(final_result_0)
final_result.reset_index(drop=True).to_file(f'{data_folder}/network_final2.shp')
print(f'{len(final_result_0)-len(final_result)} duplicates were removed' )
# Out:
# Merging lines: 100%|██████████| 4396/4396 [00:01<00:00, 4291.72it/s]
# Extracting intersections: 100%|██████████| 9527/9527 [00:07<00:00, 1353.94it/s]
# The topology has beeen fixed
# 100%|██████████| 110440/110440 [00:17<00:00, 6371.90it/s]
# 100%|██████████| 3238/3238 [07:57<00:00,  6.78it/s]
# number_of_parallel: 1551
# create new files
# 100%|██████████| 13328/13328 [00:01<00:00, 7577.14it/s]
# 100%|██████████| 47560/47560 [00:12<00:00, 3900.39it/s]
# Missing connection between Sottopassaggio del Lingotto and Via Nizza at 6 point(s)
# Missing connection between Corso Caduti sul Lavoro and Via Nizza at 3 point(s)
# Missing connection between Ciclabile Regione Piemonte - Via Sommariva and Via Nizza at 2 point(s)
# Missing connection between Via Nizza and Via Valenza at 2 point(s)
# Missing connection between Via Farigliano and Via Nizza at 1 point(s)
# Missing connection between Via Nizza and Via Sommariva at 1 point(s)
# Missing connection between Via Alba and Via Nizza at 1 point(s)
# Missing connection between Via Felizzano and Via Nizza at 1 point(s)
# Missing connection between Corso Piero Maroncelli and Via Nizza at 3 point(s)
# Missing connection between Piazza Giosuè Carducci and Via Nizza at 4 point(s)
# Missing connection between Corso Bramante and Via Nizza at 3 point(s)
# Missing connection between Via Augusto Abegg and Via Nizza at 1 point(s)
# Missing connection between Via Nizza and Via Tepice at 2 point(s)
# Missing connection between Via Alassio and Via Nizza at 2 point(s)
# Missing connection between Via Busca and Via Nizza at 1 point(s)
# Missing connection between Via Nizza and Via Stellone at 2 point(s)
# Missing connection between Via Nizza and Via Thonon at 1 point(s)
# Missing connection between Via Nizza and Via Varazze at 2 point(s)
# Missing connection between Corso Spezia and Via Nizza at 2 point(s)
# Missing connection between Sottopasso Spezia and Via Nizza at 2 point(s)
# Missing connection between Via Nizza and Via Tenda at 1 point(s)
# Missing connection between Via Bisalta and Via Nizza at 1 point(s)
# Missing connection between Via Nizza and Via Pietro Baiardi at 1 point(s)
# Missing connection between Via Narzole and Via Nizza at 1 point(s)
# Missing connection between Via Lavagna and Via Nizza at 1 point(s)
# Missing connection between Via Finalmarina and Via Nizza at 1 point(s)
# Missing connection between Via Garessio and Via Nizza at 1 point(s)
# Missing connection between Via Cortemilia and Via Nizza at 3 point(s)
# Missing connection between Via Millefonti and Via Nizza at 1 point(s)
# Missing connection between Via Leonardo da Vinci and Via Nizza at 1 point(s)
# Missing connection between Via Benvenuto Cellini and Via Nizza at 1 point(s)
# Missing connection between Via Antonio Canova and Via Nizza at 1 point(s)
# Missing connection between Via Nizza and Via Tiziano Vecellio at 1 point(s)
# Missing connection between Via Ilarione Petitti and Via Nizza at 1 point(s)
# Missing connection between Corso Dante Alighieri and Via Nizza at 1 point(s)
# Missing connection between Via Nizza and Via Ugo Foscolo at 1 point(s)
# Missing connection between Via Antonio Rosmini and Via Nizza at 1 point(s)
# Missing connection between Via Nizza and Via Vincenzo Monti at 1 point(s)
# Missing connection between Via Carlo Giovanni Brugnone and Via Nizza at 1 point(s)
# Missing connection between Via Francesco Petrarca and Via Nizza at 1 point(s)
# Missing connection between Piazza Nizza and Via Nizza at 2 point(s)
# Missing connection between Corso Raffaello and Via Nizza at 1 point(s)
# Missing connection between Via Giorgio Bidone and Via Nizza at 1 point(s)
# Missing connection between Via Federico Campana and Via Nizza at 1 point(s)
# Missing connection between Via Conte Emanuele Thesauro and Via Nizza at 1 point(s)
# Missing connection between Via Giuseppe Giacosa and Via Nizza at 1 point(s)
# Missing connection between Corso Guglielmo Marconi and Via Nizza at 5 point(s)
# Missing connection between Via Giuseppe Baretti and Via Nizza at 2 point(s)
# Missing connection between Via Claudio Luigi Berthollet and Via Nizza at 1 point(s)
# Missing connection between Via Bernardino Galliari and Via Nizza at 1 point(s)
# Missing connection between Via Nizza and Via San Pio V at 1 point(s)
# Missing connection between Corso Vittorio Emanuele II and Via Nizza at 1 point(s)
# Missing connection between Corso Sacco e Vanzetti and Via Giovanni Servais at 1 point(s)
# Missing connection between Via Carlo Bianco and Via Giovanni Servais at 2 point(s)
# Missing connection between Via Giovanni Servais and Via Mario Casaleggio at 2 point(s)
# Missing connection between Via Francesco Mittone and Via Giovanni Servais at 2 point(s)
# Missing connection between Via Santa Maria Mazzarello and Via Villa Giusti at 1 point(s)
# Missing connection between Via Monginevro and Via Santa Maria Mazzarello at 2 point(s)
# Missing connection between Via Francesco De Sanctis and Via Santa Maria Mazzarello at 2 point(s)
# Missing connection between Via Santa Maria Mazzarello and Via Valsugana at 1 point(s)
# Missing connection between Strada Antica di Grugliasco and Via Santa Maria Mazzarello at 2 point(s)
# Missing connection between Via Guido Reni and Via Santa Maria Mazzarello at 3 point(s)
# Missing connection between Corso Regina Margherita and Via Antonio Fontanesi at 1 point(s)
# Missing connection between Corso Belgio and Via Antonio Fontanesi at 1 point(s)
# Missing connection between Corso Cairoli and Corso Vittorio Emanuele II at 2 point(s)
# Missing connection between Corso Cairoli and Via Murazzi del Po Giuseppe Farassino (Gipo) at 1 point(s)
# Missing connection between Corso Cairoli and Via Giuseppe Mazzini at 2 point(s)
# Missing connection between Corso Cairoli and Via dei Mille at 2 point(s)
# Missing connection between Via Carlo Bianco and Via Fratelli Passoni at 1 point(s)
# Missing connection between Corso Vercelli and Via Druento at 1 point(s)
# Missing connection between Corso Emilia and Corso Vercelli at 2 point(s)
# Missing connection between Corso Vercelli and Ponte Domenico Carpanini at 1 point(s)
# Missing connection between Corso Vercelli and Lungo Dora Napoli at 1 point(s)
# Missing connection between Corso Sacco e Vanzetti and Via Paolo Bentivoglio at 1 point(s)
# Missing connection between Via Monginevro and Via Susa at 1 point(s)
# Missing connection between Corso Inghilterra and Via Susa at 1 point(s)
# Missing connection between Corso Francesco Ferrucci and Via Susa at 1 point(s)
# Missing connection between Via Canua and Via Susa at 1 point(s)
# Missing connection between Corso Potenza and Corso Regina Margherita at 11 point(s)
# Missing connection between Corso Lecce and Corso Regina Margherita at 12 point(s)
# Missing connection between Corso Regina Margherita and Corso Svizzera at 8 point(s)
# Missing connection between Corso Alessandro Tassoni and Corso Regina Margherita at 16 point(s)
# Missing connection between Corso Regina Margherita and Via Martinetto at 1 point(s)
# Missing connection between Corso Regina Margherita and Via Alessandro Paravia at 1 point(s)
# Missing connection between Corso Regina Margherita and Via Giuseppe Francesco Medail at 1 point(s)
# Missing connection between Corso Regina Margherita and Via Raffaele Piria at 1 point(s)
# Missing connection between Corso Regina Margherita and Via Carlo Bossi at 1 point(s)
# Missing connection between Corso Regina Margherita and Via Gabriele Bogetto at 1 point(s)
# Missing connection between Corso Regina Margherita and Via Luigi Galvani at 1 point(s)
# Missing connection between Corso Regina Margherita and Via Domenico Capellina at 1 point(s)
# Missing connection between Corso Regina Margherita and Via Antonio Vagnone at 1 point(s)
# Missing connection between Corso Regina Margherita and Via Ascanio Sobrero at 1 point(s)
# Missing connection between Corso Regina Margherita and Via Gaspare Saccarelli at 1 point(s)
# Missing connection between Corso Regina Margherita and Via Industria at 1 point(s)
# Missing connection between Corso Regina Margherita and Via Giuseppe Maria Bonzanigo at 1 point(s)
# Missing connection between Corso Regina Margherita and Via Caserta at 1 point(s)
# Missing connection between Corso Regina Margherita and Via Macerata at 1 point(s)
# Missing connection between Corso Regina Margherita and Via Bari at 1 point(s)
# Missing connection between Corso Regina Margherita and Via Livorno at 1 point(s)
# Missing connection between Corso Regina Margherita and Via Graziadio Ascoli at 1 point(s)
# Missing connection between Corso Regina Margherita and Via Aquila at 1 point(s)
# Missing connection between Corso Regina Margherita and Via Vicenza at 1 point(s)
# Missing connection between Corso Regina Margherita and Via Avellino at 1 point(s)
# Missing connection between Corso Regina Margherita and Via Arezzo at 1 point(s)
# Missing connection between Corso Regina Margherita and Via Belluno at 1 point(s)
# Missing connection between Corso Regina Margherita and Via Sondrio at 1 point(s)
# Missing connection between Corso Regina Margherita and Via Don Giovanni Bosco at 2 point(s)
# Missing connection between Corso Regina Margherita and Via Spoleto at 1 point(s)
# Missing connection between Corso Principe Oddone and Corso Regina Margherita at 2 point(s)
# Missing connection between Corso Regina Margherita and Via Giuseppe Moris at 1 point(s)
# Missing connection between Corso Regina Margherita and Via Caselle at 1 point(s)
# Missing connection between Corso Principe Eugenio and Corso Regina Margherita at 1 point(s)
# Missing connection between Corso Regina Margherita and Via della Consolata at 2 point(s)
# Missing connection between Corso Regina Margherita and Via delle Orfane at 1 point(s)
# Missing connection between Corso Regina Margherita and Piazza della Repubblica at 4 point(s)
# Missing connection between Corso Regina Margherita and Via Salerno at 1 point(s)
# Missing connection between Corso Regina Margherita and Via Masserano at 1 point(s)
# Missing connection between Corso Regina Margherita and Via Biella at 1 point(s)
# Missing connection between Corso Regina Margherita and Via Cardinale Giovanni Cagliero at 1 point(s)
# Missing connection between Corso Regina Margherita and Via Sigismondo Gerdil at 1 point(s)
# Missing connection between Corso Carlo Luigi Farini and Corso Regina Margherita at 3 point(s)
# Missing connection between Corso Regina Margherita and Largo Maresciallo Rosario Berardi at 6 point(s)
# Missing connection between Corso Regina Margherita and Via Guastalla at 3 point(s)
# Missing connection between Corso Regina Margherita and Via Saverio Vegezzi at 1 point(s)
# Missing connection between Corso Regina Margherita and Via Giacinto Borelli at 1 point(s)
# Missing connection between Corso Regina Margherita and Via Gioachino Rossini at 3 point(s)
# Missing connection between Corso Regina Margherita and Via Ercole Ricotti at 2 point(s)
# Missing connection between Corso Regina Margherita and Via Carlo Goldoni at 1 point(s)
# Missing connection between Corso Regina Margherita and Rondò Rivella at 7 point(s)
# Missing connection between Corso Regina Margherita and Corso San Maurizio at 3 point(s)
# Missing connection between Corso Regina Margherita and Via Santa Giulia 0 at 1 point(s)
# Missing connection between Corso Regina Margherita and Via Carlo Denina at 1 point(s)
# Missing connection between Corso Regina Margherita and Via Montebello at 1 point(s)
# Missing connection between Corso Regina Margherita and Via Sant'Ottavio at 1 point(s)
# Missing connection between Corso Regina Margherita and Via Michele Buniva at 1 point(s)
# Missing connection between Corso Regina Margherita and Via Giulia di Barolo at 1 point(s)
# Missing connection between Corso Regina Margherita and Via Eusebio Bava at 1 point(s)
# Missing connection between Corso Regina Margherita and Via Giovanni Francesco Napione at 2 point(s)
# Missing connection between Corso Regina Margherita and Via Riccardo Sineo at 1 point(s)
# Missing connection between Corso Regina Margherita and Piazzale Regina Margherita at 1 point(s)
# Missing connection between Corso Regina Margherita and Pronto Soccorso - Emergency at 1 point(s)
# Missing connection between Corso Regina Margherita and Via Ignazio Porro at 1 point(s)
# Missing connection between Corso Francia and Corso Inghilterra at 1 point(s)
# Missing connection between Corso Inghilterra and Via Amedeo Castellamonte at 1 point(s)
# Missing connection between Corso Inghilterra and Via Giovanni Somis at 1 point(s)
# Missing connection between Corso Inghilterra and Via Abate Antonio Vassalli-Eandi at 1 point(s)
# Missing connection between Corso Inghilterra and Via Giuseppe Grassi at 1 point(s)
# Missing connection between Cavalcone D and Corso Inghilterra at 5 point(s)
# Missing connection between Corso Inghilterra and Via Duchessa Jolanda at 5 point(s)
# Missing connection between Cavalcone C and Corso Inghilterra at 5 point(s)
# Missing connection between Cavalcone B and Corso Inghilterra at 5 point(s)
# Missing connection between Corso Inghilterra and Via Avigliana at 1 point(s)
# Missing connection between Corso Inghilterra and cavalcone A at 5 point(s)
# Missing connection between Corso Inghilterra and Via Giovanni Carlo Cavalli at 8 point(s)
# Missing connection between Corso Castelfidardo and Corso Inghilterra at 4 point(s)
# Missing connection between Corso Inghilterra and Corso Vittorio Emanuele II at 6 point(s)
# Missing connection between Corso Inghilterra and Via Pietro Santarosa at 1 point(s)
# Missing connection between Corso Galileo Ferraris and Piazzale San Gabriele di Gorizia at 4 point(s)
# Missing connection between Corso Galileo Ferraris and Via Enrico Koelliker at 2 point(s)
# Missing connection between Corso Galileo Ferraris and Corso Sebastopoli at 6 point(s)
# Missing connection between Corso Galileo Ferraris and Via Tommaso De Cristoforis at 2 point(s)
# Missing connection between Corso Galileo Ferraris and Piazzale Costantino Il Grande at 8 point(s)
# Missing connection between Corso Galileo Ferraris and Corso Monte Lungo at 3 point(s)
# Missing connection between Corso Galileo Ferraris and Via Tirreno at 3 point(s)
# Missing connection between Corso Enrico De Nicola and Corso Galileo Ferraris at 6 point(s)
# Missing connection between Corso Carlo e Nello Rosselli and Corso Galileo Ferraris at 6 point(s)
# Missing connection between Corso Galileo Ferraris and Via Fratelli Carle at 3 point(s)
# Missing connection between Corso Galileo Ferraris and Via Sebastiano Caboto at 3 point(s)
# Missing connection between Corso Galileo Ferraris and Via Amerigo Vespucci at 3 point(s)
# Missing connection between Corso Galileo Ferraris and Via Cristoforo Colombo at 3 point(s)
# Missing connection between Corso Galileo Ferraris and Corso Luigi Einaudi at 6 point(s)
# Missing connection between Corso Galileo Ferraris and Via Pastrengo at 2 point(s)
# Missing connection between Corso Galileo Ferraris and Corso Rodolfo Montevecchio at 4 point(s)
# Missing connection between Corso Galileo Ferraris and Via Rodolfo Montevecchio at 2 point(s)
# Missing connection between Corso Galileo Ferraris and Corso Stati Uniti at 5 point(s)
# Missing connection between Corso Galileo Ferraris and Largo Vittorio Emanuele II at 5 point(s)
# Missing connection between Corso Unione Sovietica and Via Tommaso De Cristoforis at 2 point(s)
# Missing connection between Via Giordano Bruno and Via Pasquale Galluppi at 2 point(s)
# Missing connection between Via Cristoforo Colombo and Via Leonardo da Vinci at 1 point(s)
# Missing connection between Via Cristoforo Colombo and Via Marco Polo at 1 point(s)
# Missing connection between Corso Mediterraneo and Via Cristoforo Colombo at 1 point(s)
# Missing connection between Corso Duca degli Abruzzi and Via Cristoforo Colombo at 3 point(s)
# Missing connection between Corso Alcide De Gasperi and Via Cristoforo Colombo at 1 point(s)
# Missing connection between Corso Re Umberto and Via Cristoforo Colombo at 2 point(s)
# Missing connection between Via Cristoforo Colombo and Via Torino at 1 point(s)
# Missing connection between Corso Re Umberto and Piazzale Costantino Il Grande at 1 point(s)
# Missing connection between Corso Re Umberto and Via Anton Giulio Barrili at 1 point(s)
# Missing connection between Corso Re Umberto and Via Tirreno at 4 point(s)
# Missing connection between Corso Enrico De Nicola and Corso Re Umberto at 6 point(s)
# Missing connection between Corso Carlo e Nello Rosselli and Corso Re Umberto at 6 point(s)
# Missing connection between Corso Re Umberto and Largo Re Umberto at 5 point(s)
# Missing connection between Corso Re Umberto and Via Amerigo Vespucci at 3 point(s)
# Missing connection between Corso Re Umberto and Via Antonio Genovesi at 2 point(s)
# Missing connection between Corso Re Umberto and Via Gaetano Filangieri at 2 point(s)
# Missing connection between Corso Re Umberto and Via Giambattista Vico at 3 point(s)
# Missing connection between Corso Luigi Einaudi and Corso Re Umberto at 3 point(s)
# Missing connection between Corso Re Umberto and Via Valeggio at 3 point(s)
# Missing connection between Corso Re Umberto and Via Pastrengo at 3 point(s)
# Missing connection between Corso Re Umberto and Via Legnano at 3 point(s)
# Missing connection between Corso Re Umberto and Via Rodolfo Montevecchio at 3 point(s)
# Missing connection between Corso Re Umberto and Corso Stati Uniti at 4 point(s)
# Missing connection between Corso Re Umberto and Via Assietta at 3 point(s)
# Missing connection between Corso Re Umberto and Via Magenta at 3 point(s)
# Missing connection between Corso Re Umberto and Corso Vittorio Emanuele II at 9 point(s)
# Missing connection between Corso Lecce and Via Michele Lessona at 4 point(s)
# Missing connection between Via Domodossola and Via Michele Lessona at 1 point(s)
# Missing connection between Corso Monte Grappa and Via Michele Lessona at 1 point(s)
# Missing connection between Via Filadelfia and Via Tunisi at 1 point(s)
# Missing connection between Corso Sebastopoli and Via Tunisi at 3 point(s)
# Missing connection between Corso Unione Sovietica and Via Tunisi at 1 point(s)
# Missing connection between Passerella Olimpica and Via Zino Giacomo Zini at 2 point(s)
# Missing connection between Sottopassaggio del Lingotto and Via Zino Giacomo Zini at 4 point(s)
# Missing connection between Corso Bramante and Via Zino Giacomo Zini at 4 point(s)
# Missing connection between Via Arduino and Via Zino Giacomo Zini at 1 point(s)
# Missing connection between Corso Bramante and Via Giordano Bruno at 3 point(s)
# Missing connection between Corso Bramante and Corso Unione Sovietica at 4 point(s)
# Missing connection between Corso Bramante and Corso Filippo Turati at 4 point(s)
# Missing connection between Corso Bramante and Corso Lepanto at 2 point(s)
# Missing connection between Corso Bramante and Piazza Giosuè Carducci at 4 point(s)
# Missing connection between Corso Bramante and Via Madama Cristina at 2 point(s)
# Missing connection between Corso Bramante and Via Genova at 3 point(s)
# Missing connection between Corso Bramante and Via Giotto at 3 point(s)
# Missing connection between Corso Achille Mario Dogliotti and Corso Bramante at 4 point(s)
# Missing connection between Corso Bramante and Sottopasso Michele Lanza at 6 point(s)
# Missing connection between Corso Bramante and Corso Massimo D'Azeglio at 2 point(s)
# Missing connection between Corso Moncalieri and Via Oristano at 1 point(s)
# Missing connection between Corso Moncalieri and Strada del Campagnino at 1 point(s)
# Missing connection between Corso Moncalieri and Strada alla Villa Zanetti at 1 point(s)
# Missing connection between Corso Moncalieri and Via Macrino d'Alba at 1 point(s)
# Missing connection between Corso Moncalieri and Strada degli Alberoni at 1 point(s)
# Missing connection between Corso Moncalieri and Piazza Merano at 2 point(s)
# Missing connection between Corso Moncalieri and Strada alla Villa d'Ormea at 1 point(s)
# Missing connection between Corso Moncalieri and Piazza Zara at 3 point(s)
# Missing connection between Corso Moncalieri and Strada del Salino at 1 point(s)
# Missing connection between Corso Moncalieri and Via Aquileia at 1 point(s)
# Missing connection between Corso Moncalieri and Via Grado at 1 point(s)
# Missing connection between Corso Moncalieri and Via Giovanni Antonio Amadeo at 1 point(s)
# Missing connection between Corso Moncalieri and Via Calatafimi at 1 point(s)
# Missing connection between Corso Moncalieri and Corso Sicilia at 2 point(s)
# Missing connection between Corso Moncalieri and Ponte Principessa Isabella di Savoia at 1 point(s)
# Missing connection between Corso Moncalieri and Strada dal Ponte Isabella a San Vito at 1 point(s)
# Missing connection between Corso Moncalieri and Via Febo at 1 point(s)
# Missing connection between Corso Giovanni Lanza and Corso Moncalieri at 2 point(s)
# Missing connection between Corso Moncalieri and Via Marsala at 1 point(s)
# Missing connection between Corso Moncalieri and Via Milazzo at 1 point(s)
# Missing connection between Corso Moncalieri and Via Argonne at 1 point(s)
# Missing connection between Corso Moncalieri and Piazzetta Don Costantino Pagliotti at 1 point(s)
# Missing connection between Corso Moncalieri and Via Volturno at 1 point(s)
# Missing connection between Corso Fiume and Corso Moncalieri at 1 point(s)
# Missing connection between Sottopasso Repubblica and Via Porta Palatina at 2 point(s)
# Missing connection between Corso Regina Margherita and Via Porta Palatina at 2 point(s)
# Missing connection between Corso Giulio Cesare and Pista ciclabile di Corso Giulio Cesare at 5 point(s)
# Missing connection between Corso Giulio Cesare and Piazzale Cornelio Tacito at 4 point(s)
# Missing connection between Corso Giulio Cesare and Via Nino Oxilia at 4 point(s)
# Missing connection between Corso Giulio Cesare and Piazza Derna at 6 point(s)
# Missing connection between Corso Giulio Cesare and Corso Giulio Cesare 424 at 10 point(s)
# Missing connection between Corso Giulio Cesare and Via Samone at 2 point(s)
# Missing connection between Corso Vercelli and Via Sandro Botticelli at 1 point(s)
# Missing connection between Corso Grosseto and Via Sandro Botticelli at 1 point(s)
# Missing connection between Piazza Conti di Rebaudengo and Via Sandro Botticelli at 2 point(s)
# Missing connection between Piazza Derna and Via Sandro Botticelli at 1 point(s)
# Missing connection between Corso Grosseto and Corso Vercelli at 3 point(s)
# Missing connection between Corso Grosseto and Piazza Conti di Rebaudengo at 2 point(s)
# Missing connection between Corso Grosseto and Via Ala di Stura at 9 point(s)
# Missing connection between Corso Grosseto and Via Chiesa della Salute at 4 point(s)
# Missing connection between Corso Grosseto and Via Bibiana at 2 point(s)
# Missing connection between Corso Grosseto and Via Paolo della Cella at 1 point(s)
# Missing connection between Corso Grosseto and Via Conte di Roccavione at 2 point(s)
# Missing connection between Corso Grosseto and Via Leonardo Fea at 1 point(s)
# Missing connection between Corso Grosseto and Via Casteldelfino at 4 point(s)
# Missing connection between Corso Grosseto and Via Giambattista Lulli at 1 point(s)
# Missing connection between Corso Grosseto and Sottopasso Grosseto - Potenza at 2 point(s)
# Missing connection between Via Cardinale Guglielmo Massaia and Via Sospello at 2 point(s)
# Missing connection between Via Lorenzo Ghiberti and Via Sospello at 1 point(s)
# Missing connection between Via Casteldelfino and Via Sospello at 1 point(s)
# Missing connection between Via Saorgio and Via Sospello at 1 point(s)
# Missing connection between Via Giovanni Randaccio and Via Sospello at 1 point(s)
# Missing connection between Via Francesco Baracca and Via Sospello at 1 point(s)
# Missing connection between Via Chiesa della Salute and Via Sospello at 1 point(s)
# Missing connection between Via Costantino Nigra and Via Sospello at 1 point(s)
# Missing connection between Via Bibiana and Via Sospello at 1 point(s)
# Missing connection between Via Gaetano Mosca and Via Sospello at 2 point(s)
# Missing connection between Via Conte di Roccavione and Via Sospello at 1 point(s)
# Missing connection between Via Campiglia and Via Sospello at 1 point(s)
# Missing connection between Corso Grosseto and Via Sospello at 1 point(s)
# Missing connection between Via Breglio and Via Conte di Roccavione at 1 point(s)
# Missing connection between Via Conte di Roccavione and Via Saorgio at 1 point(s)
# Missing connection between Via Conte di Roccavione and Via Villar at 1 point(s)
# Missing connection between Via Conte di Roccavione and Via Michele Antonio Vibò at 1 point(s)
# Missing connection between Via Cardinale Guglielmo Massaia and Via Conte di Roccavione at 1 point(s)
# Missing connection between Strada delle Vallette and Via delle Primule at 1 point(s)
# Missing connection between Corso Ferrara and Via delle Primule at 1 point(s)
# Missing connection between Via delle Pervinche and Via delle Primule at 4 point(s)
# Missing connection between Via delle Primule and Viale dei Mughetti at 6 point(s)
# Missing connection between Strada Pianezza and Via delle Primule at 6 point(s)
# Missing connection between Corso Regina Margherita and Strada Pianezza at 2 point(s)
# Missing connection between Strada Pianezza and Via Pianezza at 1 point(s)
# Missing connection between Strada Pianezza and Via Pietro Cossa at 3 point(s)
# Missing connection between Strada Pianezza and Via Andrea Sansovino at 2 point(s)
# Missing connection between Piazza Cirene and Strada Pianezza at 2 point(s)
# Missing connection between Strada Pianezza and Via Maria Adelaide Aglietta at 6 point(s)
# Missing connection between Via Francesco Giuseppe Guicciardini and Viale Petrarca at 1 point(s)
# Missing connection between Via Donatello and Viale Petrarca at 1 point(s)
# Missing connection between Via Tiziano Vecellio and Viale Petrarca at 1 point(s)
# Missing connection between Corso Papa Giovanni Ventitreesimo and Via Filippo Juvarra at 2 point(s)
# Missing connection between Corso Papa Giovanni Ventitreesimo and Viale Paolo Emilio Buridani at 1 point(s)
# Missing connection between Corso Giacomo Matteotti and Corso Papa Giovanni Ventitreesimo at 1 point(s)
# Missing connection between Corso Papa Giovanni Ventitreesimo and Via Giacomo Leopardi at 1 point(s)
# Missing connection between Corso Papa Giovanni Ventitreesimo and Via Gabriele D'Annunzio at 2 point(s)
# Missing connection between Corso Papa Giovanni Ventitreesimo and Via San Giuseppe at 1 point(s)
# Missing connection between Corso Papa Giovanni Ventitreesimo and Via Arduino Iseppon at 2 point(s)
# Missing connection between Corso Giuseppe Garibaldi and Corso Papa Giovanni Ventitreesimo at 4 point(s)
# Missing connection between Corso Giacomo Matteotti and Via Don Giovanni Battista Sapino at 2 point(s)
# Missing connection between Via Don Giovanni Battista Sapino and Via Giuido Rossa at 1 point(s)
# Missing connection between Via Aldo Moro and Via Don Giovanni Battista Sapino at 2 point(s)
# Missing connection between Via Don Giovanni Battista Sapino and Via Nazario Sauro at 1 point(s)
# Missing connection between Via Antonio Sciesa and Via Don Giovanni Battista Sapino at 1 point(s)
# Missing connection between Strada Collegno-Venaria and Via Torino-Druento at 1 point(s)
# Missing connection between Corso Giuseppe Garibaldi and Via Gabriele D'Annunzio at 1 point(s)
# Missing connection between Corso Giuseppe Garibaldi and Via San Francesco d'Assisi at 1 point(s)
# Missing connection between Corso Giuseppe Garibaldi and Via Goito at 1 point(s)
# Missing connection between Corso Giuseppe Garibaldi and Via Quattro Novembre at 1 point(s)
# Missing connection between Corso Giuseppe Garibaldi and Viale delle Industrie at 1 point(s)
# Missing connection between Corso Giuseppe Garibaldi and Via Druento at 7 point(s)
# Missing connection between Corso Giuseppe Garibaldi and Strada di Altessano at 2 point(s)
# Missing connection between Strada Commenda and Via Torino at 1 point(s)
# Missing connection between Via Guerrino Nicoli and Via Torino at 1 point(s)
# Missing connection between Via Fornaci and Via Torino at 1 point(s)
# Missing connection between Via Monte Tabor and Via Torino at 1 point(s)
# Missing connection between Via Superga and Via Torino at 1 point(s)
# Missing connection between Via Marco Polo and Via Torino at 1 point(s)
# Missing connection between Via Amerigo Vespucci and Via Torino at 1 point(s)
# Missing connection between Via Camillo Benso Conte di Cavour and Via Torino at 1 point(s)
# Missing connection between Via Giosuè Carducci and Via Torino at 1 point(s)
# Missing connection between Via Giotto and Via Torino at 1 point(s)
# Missing connection between Via Pietro Giannone and Via Torino at 1 point(s)
# Missing connection between Via Assietta and Via Assietta 77 at 1 point(s)
# Missing connection between Asse di penetrazione urbana di Corso Regina Margherita and Corso Regina Margherita at 2 point(s)
# Missing connection between Corso Regina Margherita and Via Pietro Cossa at 5 point(s)
# Missing connection between Corso Regina Margherita and Sottopasso Repubblica at 3 point(s)
# Missing connection between Corso Regina Margherita and Lungo Po Niccolò Machiavelli at 2 point(s)
# Missing connection between Corso Regina Margherita and Lungo Po Alessandro Antonelli at 1 point(s)
# Missing connection between Corso Regina Margherita and Corso Tortona at 1 point(s)
# Missing connection between Corso Regina Margherita and Via Bettino Ricasoli at 1 point(s)
# Missing connection between Via Alessandro Cruto and Via Errico Petrella at 1 point(s)
# Missing connection between Via Alessandro Cruto and Via Domenico Cimarosa at 1 point(s)
# Missing connection between Via Alessandro Cruto and Via Alfredo Casella at 1 point(s)
# Missing connection between Corso Vercelli and Via Sempione at 1 point(s)
# Missing connection between Via Francesco Cigna and Via Sempione at 1 point(s)
# Missing connection between Via Renato Martorelli and Via Sempione at 1 point(s)
# Missing connection between Corso Giulio Cesare and Via Sempione at 2 point(s)
# Missing connection between Via Saverio Mercadante and Via Sempione at 1 point(s)
# Missing connection between Via Giovanni Paisiello and Via Sempione at 1 point(s)
# Missing connection between Via Maddalene and Via Sempione at 1 point(s)
# Missing connection between Via Bologna and Via Sempione at 1 point(s)
# Missing connection between Strada di Settimo and Via Centallo at 2 point(s)
# Missing connection between Via Domenico Cimarosa and Via Errico Petrella at 1 point(s)
# Missing connection between Via Bologna and Via Domenico Cimarosa at 1 point(s)
# Missing connection between Via Bologna and Via Moncrivello at 1 point(s)
# Missing connection between Via Giorgio Ghedini and Via Moncrivello at 1 point(s)
# Missing connection between Strada Maddalene and Via Giorgio Ghedini at 1 point(s)
# Missing connection between Via Giorgio Ghedini and Via Maddalene at 1 point(s)
# Missing connection between Via Cesare Balbo and Via Eusebio Bava at 1 point(s)
# Missing connection between Via Eusebio Bava and Via Santa Giulia at 1 point(s)
# Missing connection between Via Eusebio Bava and Via degli Artisti at 1 point(s)
# Missing connection between Corso San Maurizio and Via Eusebio Bava at 3 point(s)
# Missing connection between Via Eusebio Bava and Via Matteo Pescatore at 2 point(s)
# Missing connection between Via Sant'Ottavio and Via degli Artisti at 1 point(s)
# Missing connection between Corso San Maurizio and Via Guastalla at 2 point(s)
# Missing connection between Via Cesare Balbo and Via Sant'Ottavio at 1 point(s)
# Missing connection between Piazza Santa Giulia and Via Cesare Balbo at 2 point(s)
# Missing connection between Lungo Stura Lazio and Strada di Settimo at 4 point(s)
# Missing connection between Largo Damiano Chiesa and Strada di Settimo at 5 point(s)
# Missing connection between Strada di Settimo and Via Ugo Ceresero at 2 point(s)
# Missing connection between Strada di Settimo and Via Fernando De Rosa at 2 point(s)
# Missing connection between Strada di Settimo and Via Damiano Chiesa at 4 point(s)
# Missing connection between Strada di San Mauro and Strada di Settimo at 2 point(s)
# Missing connection between Strada della Magra and Strada di Settimo at 1 point(s)
# Missing connection between Strada del Cascinotto and Strada di Settimo at 1 point(s)
# Missing connection between Strada di Settimo and Via Puglia at 3 point(s)
# Missing connection between Parcheggio Tesla, Strada di Settimo. and Strada di Settimo at 1 point(s)
# Missing connection between Strada da Bertolla all'Abbadia di Stura and Strada di Settimo at 1 point(s)
# Missing connection between Strada della Cebrosa and Strada di Settimo at 2 point(s)
# Missing connection between Corso Lombardia and Strada di Settimo at 2 point(s)
# Missing connection between Lungo Stura Lazio and Via Puglia at 1 point(s)
# Missing connection between Lungo Stura Lazio and Pista ciclabile di Corso Giulio Cesare at 2 point(s)
# Missing connection between Largo Damiano Chiesa and Lungo Stura Lazio at 2 point(s)
# Missing connection between Lungo Stura Lazio and Ponte Diga at 5 point(s)
# Missing connection between Lungo Stura Lazio and Via Rubens Fattorelli at 2 point(s)
# Missing connection between Lungo Stura Lazio and Strada del Pascolo at 1 point(s)
# Missing connection between Pista ciclabile di Piazza Derna and Via Sandro Botticelli at 2 point(s)
# Missing connection between Via Monte Rosa and Via Sandro Botticelli at 4 point(s)
# Missing connection between Strada Basse di Stura and Via Sandro Botticelli at 1 point(s)
# Missing connection between Via Giuseppe Tartini and Via Sandro Botticelli at 1 point(s)
# Missing connection between Via Arcangelo Corelli and Via Sandro Botticelli at 1 point(s)
# Missing connection between Via Giovenale Ancina and Via Sandro Botticelli at 2 point(s)
# Missing connection between Corso Taranto and Via Sandro Botticelli at 1 point(s)
# Missing connection between Piazza Sofia and Via Sandro Botticelli at 2 point(s)
# Missing connection between Piazza Sofia and Via Bologna at 1 point(s)
# Missing connection between Via Arcangelo Corelli and Via Gottardo at 3 point(s)
# Missing connection between Via Arcangelo Corelli and Via Giovanni Cravero at 2 point(s)
# Missing connection between Via Arcangelo Corelli and Via Giuseppe Tartini at 1 point(s)
# Missing connection between Via Arcangelo Corelli and Via Pietro Mascagni at 2 point(s)
# Missing connection between Corso Taranto and Via Arcangelo Corelli at 2 point(s)
# Missing connection between Via Arcangelo Corelli and Via Lorenzo Perosi at 2 point(s)
# Missing connection between Via Arcangelo Corelli and Via Giambattista Pergolesi at 1 point(s)
# Missing connection between Pista ciclabile di Corso Taranto and Via Arcangelo Corelli at 2 point(s)
# Missing connection between Largo Montebello and Via Montebello at 2 point(s)
# Missing connection between Via Gioachino Rossini and Via Giuseppe Verdi at 2 point(s)
# Missing connection between Corso San Maurizio and Via Gioachino Rossini at 3 point(s)
# Missing connection between Piazza Castello and Via Roma at 1 point(s)
# Missing connection between Piazza Castello and Via Accademia delle Scienze at 1 point(s)
# Missing connection between Piazza Castello and Via Po at 1 point(s)
# Missing connection between Piazza Castello and Via Giuseppe Verdi at 2 point(s)
# Missing connection between Piazza Castello and Viale Primo Maggio at 1 point(s)
# Missing connection between Via Giuseppe Verdi and Via Montebello at 1 point(s)
# Missing connection between Corso San Maurizio and Via Montebello at 3 point(s)
# Missing connection between Via Montebello and Via Roma at 1 point(s)
# Missing connection between Via Milano and Via Montebello at 1 point(s)
# Missing connection between Corso San Maurizio and Via Conte Luigi Tarino at 1 point(s)
# Missing connection between Via Madama Cristina and Via Tommaso Valperga di Caluso at 1 point(s)
# Missing connection between Corso Massimo D'Azeglio and Via Tommaso Valperga di Caluso at 2 point(s)
# Missing connection between Corso Belgio and Lungo Po Alessandro Antonelli at 6 point(s)
# Missing connection between Corso Belgio and Via Asigliano Vercellese at 2 point(s)
# Missing connection between Corso Belgio and Corso Cadore at 4 point(s)
# Missing connection between Corso Belgio and Via Pallanza at 2 point(s)
# Missing connection between Corso Belgio and Via Monte Santo at 1 point(s)
# Missing connection between Corso Belgio and Via Giuseppe Ricci at 2 point(s)
# Missing connection between Corso Belgio and Corso Chieti at 4 point(s)
# Missing connection between Corso Belgio and Via Benevento at 2 point(s)
# Missing connection between Corso Belgio and Via Cigliano at 2 point(s)
# Missing connection between Corso Belgio and Via Lessolo at 2 point(s)
# Missing connection between Corso Belgio and Via Cossila at 2 point(s)
# Missing connection between Corso Belgio and Via Mongrando at 2 point(s)
# Missing connection between Corso Belgio and Corso Tortona at 8 point(s)
# Missing connection between Corso Belgio and Via Bettino Ricasoli at 2 point(s)
# Missing connection between Corso Belgio and Largo Maresciallo Rosario Berardi at 2 point(s)
# Missing connection between Corso Belgio and Corso Carlo Luigi Farini at 4 point(s)
# Missing connection between Corso Belgio and Via Daniele Manin at 1 point(s)
# Missing connection between Corso Belgio and Pista ciclabile di Lungo Po Antonelli at 1 point(s)
# Missing connection between Corso Carlo Luigi Farini and Largo Maresciallo Rosario Berardi at 2 point(s)
# Missing connection between Corso Giulio Cesare and Via Baltea at 2 point(s)
# Missing connection between Corso Giulio Cesare and Largo Giulio Cesare at 2 point(s)
# Missing connection between Corso Giulio Cesare and Via Sesia at 2 point(s)
# Missing connection between Corso Giulio Cesare and Via Malone at 2 point(s)
# Missing connection between Corso Giulio Cesare and Via Leinì at 1 point(s)
# Missing connection between Corso Giulio Cesare and Corso Novara at 6 point(s)
# Missing connection between Corso Giulio Cesare and Pista ciclabile di Piazza Derna at 2 point(s)
# Missing connection between Corso Giulio Cesare and Via Giambattista Pergolesi at 3 point(s)
# Missing connection between Corso Giulio Cesare and Via Nicola Porpora at 5 point(s)
# Missing connection between Corso Giulio Cesare and Via Giovanni Poggio at 1 point(s)
# Missing connection between Corso Giulio Cesare and Via Gottardo at 2 point(s)
# Missing connection between Corso Giulio Cesare and Via Sandigliano at 1 point(s)
# Missing connection between Corso Giulio Cesare and Via Salassa at 1 point(s)
# Missing connection between Corso Giulio Cesare and Via Rivarossa at 1 point(s)
# Missing connection between Corso Giulio Cesare and Via Lauro Rossi at 1 point(s)
# Missing connection between Corso Giulio Cesare and Via Luigi Salvatore Cherubini at 1 point(s)
# Missing connection between Corso Giulio Cesare and Via Gaspare Spontini at 1 point(s)
# Missing connection between Corso Giulio Cesare and Via Monte Nero at 1 point(s)
# Missing connection between Corso Giulio Cesare and Via Lorenzo Bruno at 1 point(s)
# Missing connection between Piazza Vincenzo Arbarello and Via della Consolata at 1 point(s)
# Missing connection between Piazza Savoia and Via della Consolata at 2 point(s)
# Missing connection between Via Gottardo and Via San Gaetano da Thiene at 1 point(s)
# Missing connection between Via Gottardo and Via Maddalene at 1 point(s)
# Missing connection between Via Bologna and Via Gottardo at 3 point(s)
# Missing connection between Via Giovenale Ancina and Via Gottardo at 3 point(s)
# Missing connection between Via Giovanni Cravero and Via Gottardo at 1 point(s)
# Missing connection between Via Gottardo and Via Saverio Mercadante at 1 point(s)
# Missing connection between Piazza del Donatore di Sangue and Via Gottardo at 2 point(s)
# Missing connection between Via Gottardo and Via Monte Rosa at 1 point(s)
# Missing connection between Via Gottardo and Via Renato Martorelli at 1 point(s)
# Missing connection between Corso Vercelli and Via Gottardo at 1 point(s)
# Missing connection between Corso San Maurizio and Via Lorenzo Martini at 1 point(s)
# Missing connection between Piazza Santa Giulia and Via Santa Giulia at 1 point(s)
# Missing connection between Corso Regio Parco and Lungo Dora Siena at 1 point(s)
# Missing connection between Lungo Dora Siena and Via Ercole Ricotti at 1 point(s)
# Missing connection between Lungo Dora Siena and Via Giacinto Borelli at 1 point(s)
# Missing connection between Lungo Dora Siena and Passerella Franco Mellano at 1 point(s)
# Missing connection between Lungo Dora Siena and Viale Ottavio Mario Mai at 1 point(s)
# Missing connection between Corso Tortona and Lungo Dora Siena at 1 point(s)
# Missing connection between Corso Undici Febbraio and Via Gianfrancesco Fiochetto at 2 point(s)
# Missing connection between Via Clemente Damiano Priocca and Via Gianfrancesco Fiochetto at 1 point(s)
# Missing connection between Corso San Maurizio and Viale dei Partigiani at 2 point(s)
# Missing connection between Corso Filippo Turati and Corso Germano Sommeiller at 1 point(s)
# Missing connection between Corso Dante Alighieri and Corso Filippo Turati at 1 point(s)
# Missing connection between Corso Dante Alighieri and Largo Filippo Turati at 5 point(s)
# Missing connection between Corso Dante Alighieri and Via Solero at 3 point(s)
# Missing connection between Corso Dante Alighieri and Via Roccabruna at 3 point(s)
# Missing connection between Corso Dante Alighieri and Via Tommaso Grossi at 2 point(s)
# Missing connection between Corso Dante Alighieri and Piazza Edmondo De Amicis at 3 point(s)
# Missing connection between Corso Dante Alighieri and Via Saluzzo at 1 point(s)
# Missing connection between Corso Dante Alighieri and Via Madama Cristina at 1 point(s)
# Missing connection between Corso Dante Alighieri and Via Giotto at 1 point(s)
# Missing connection between Corso Dante Alighieri and Via Ormea at 1 point(s)
# Missing connection between Corso Dante Alighieri and Via Pietro Giuria at 1 point(s)
# Missing connection between Corso Dante Alighieri and Corso Massimo D'Azeglio at 4 point(s)
# Missing connection between Corso Dante Alighieri and Via Carlo Marochetti at 1 point(s)
# Missing connection between Corso Dante Alighieri and Via Gabriele Chiabrera at 1 point(s)
# Missing connection between Corso Dante Alighieri and Via Carlo Marenco at 1 point(s)
# Missing connection between Corso Dante Alighieri and Via Gian Battista Tiepolo at 1 point(s)
# Missing connection between Corso Dante Alighieri and Viale Marinai d'Italia at 2 point(s)
# Missing connection between Corso Massimo D'Azeglio and Corso Vittorio Emanuele II at 3 point(s)
# Missing connection between Corso Massimo D'Azeglio and Via San Pio V at 2 point(s)
# Missing connection between Corso Massimo D'Azeglio and Via Bernardino Galliari at 2 point(s)
# Missing connection between Corso Massimo D'Azeglio and Via Claudio Luigi Berthollet at 2 point(s)
# Missing connection between Corso Massimo D'Azeglio and Via Silvio Pellico at 2 point(s)
# Missing connection between Corso Massimo D'Azeglio and Via Giuseppe Baretti at 2 point(s)
# Missing connection between Corso Massimo D'Azeglio and Via Cesare Lombroso at 2 point(s)
# Missing connection between Corso Guglielmo Marconi and Corso Massimo D'Azeglio at 5 point(s)
# Missing connection between Corso Massimo D'Azeglio and Via Giuseppe Giacosa at 2 point(s)
# Missing connection between Corso Massimo D'Azeglio and Via Federico Campana at 2 point(s)
# Missing connection between Corso Massimo D'Azeglio and Via Oddino Morgari at 2 point(s)
# Missing connection between Corso Massimo D'Azeglio and Via Giorgio Bidone at 1 point(s)
# Missing connection between Corso Massimo D'Azeglio and Corso Raffaello at 3 point(s)
# Missing connection between Corso Massimo D'Azeglio and Via Michelangelo Buonarroti at 1 point(s)
# Missing connection between Corso Massimo D'Azeglio and Via Gaetano Donizetti at 2 point(s)
# Missing connection between Corso Massimo D'Azeglio and Via Francesco Petrarca at 5 point(s)
# Missing connection between Corso Massimo D'Azeglio and Sottopasso Michele Lanza at 12 point(s)
# Missing connection between Piazza C.L.N. and Via Giovanni Giolitti at 1 point(s)
# Missing connection between Corso Vittorio Emanuele II and Via della Rocca at 1 point(s)
# Missing connection between Piazza Maria Teresa and Via della Rocca at 1 point(s)
# Missing connection between Via Settimo and Via dei Mille at 1 point(s)
# Missing connection between Corso Vittorio Emanuele II and Via Accademia Albertina at 1 point(s)
# Missing connection between Via Errico Petrella and Via Maddalene at 1 point(s)
# Missing connection between Via Bologna and Via Maddalene at 2 point(s)
# Missing connection between Via Arnaldo Fusinato and Via Maddalene at 1 point(s)
# Missing connection between Via Aosta and Via Errico Petrella at 2 point(s)
# Missing connection between Piazza Augusto Rostagni and Via Errico Petrella at 2 point(s)
# Missing connection between Via Errico Petrella and Via Luigi Pietracqua at 1 point(s)
# Missing connection between Piazza della Repubblica and Sottopasso Repubblica at 4 point(s)
# Missing connection between Corso Giulio Cesare and Piazza della Repubblica at 1 point(s)
# Missing connection between Corso Regio Parco and Ponte delle Benne at 1 point(s)
# Missing connection between Corso Regio Parco and Rondò Rivella at 1 point(s)
# Missing connection between Corso Regio Parco and Ponte Regio Parco at 1 point(s)
# Missing connection between Corso Regio Parco and Lungo Dora Firenze at 2 point(s)
# Missing connection between Corso Regio Parco and Largo Regio Parco at 4 point(s)
# Missing connection between Piazza Savoia and Via Corte d'Appello at 1 point(s)
# Missing connection between Piazza Savoia and Via del Carmine at 1 point(s)
# Missing connection between Corso Valdocco and Via del Carmine at 2 point(s)
# Missing connection between Corso Giambattista Beccaria and Via del Carmine at 1 point(s)
# Missing connection between Piazza Vincenzo Arbarello and Via Bligny at 1 point(s)
# Missing connection between Via Principe Amedeo and Via Roma at 1 point(s)
# Missing connection between Via Antonio Giuseppe Bertola and Via Roma at 1 point(s)
# Missing connection between Corso Vittorio Emanuele II and Piazza Carlo Felice at 4 point(s)
# Missing connection between Piazza Carlo Felice and Piazza Giuseppe Luigi Lagrange at 1 point(s)
# Missing connection between Piazza Carlo Felice and Via Roma at 1 point(s)
# Missing connection between Piazza Carlo Felice and Piazza Pietro Paleocapa at 1 point(s)
# Missing connection between Via Antonio Giuseppe Bertola and Via San Tommaso at 2 point(s)
# Missing connection between Via Pietro Micca and Via San Tommaso at 1 point(s)
# Missing connection between Via Carlo Alberto and Via Principe Amedeo at 1 point(s)
# Missing connection between Via Carlo Alberto and Via Maria Vittoria at 1 point(s)
# Missing connection between Via Carlo Alberto and Via Giovanni Giolitti at 1 point(s)
# Missing connection between Via Camillo Benso Conte di Cavour and Via Carlo Alberto at 1 point(s)
# Missing connection between Via Andrea Doria and Via Carlo Alberto at 2 point(s)
# Missing connection between Via Carlo Alberto and Via Giambattista Bodoni at 2 point(s)
# Missing connection between Via Carlo Alberto and Via Giuseppe Mazzini at 1 point(s)
# Missing connection between Corso Vercelli and Via Nino Oxilia at 1 point(s)
# Missing connection between Via Cogne and Via Nino Oxilia at 2 point(s)
# Missing connection between Via Guglielmo Reiss Romoli and Via Nino Oxilia at 1 point(s)
# Missing connection between Via Nino Oxilia and Via Tommaso Vallauri at 2 point(s)
# Missing connection between Corso Carlo e Nello Rosselli and Corso Trapani at 6 point(s)
# Missing connection between Corso Carlo e Nello Rosselli and Via Isonzo at 1 point(s)
# Missing connection between Corso Carlo e Nello Rosselli and Via Issiglio at 2 point(s)
# Missing connection between Corso Carlo e Nello Rosselli and Via Caraglio at 2 point(s)
# Missing connection between Corso Carlo e Nello Rosselli and Via Tolmino at 1 point(s)
# Missing connection between Corso Carlo e Nello Rosselli and Corso Racconigi at 3 point(s)
# Missing connection between Corso Carlo e Nello Rosselli and Piazza Marmolada at 2 point(s)
# Missing connection between Corso Carlo e Nello Rosselli and Via Murazzano at 1 point(s)
# Missing connection between Corso Carlo e Nello Rosselli and Via Malta at 1 point(s)
# Missing connection between Corso Carlo e Nello Rosselli and Via Lussimpiccolo at 1 point(s)
# Missing connection between Corso Carlo e Nello Rosselli and Largo Orbassano at 4 point(s)
# ...
# Missing connection between Corso Benedetto Brin and Via Montesoglio at 1 point(s)
# Missing connection between Corso Benedetto Brin and Via Luigi Gramegna at 1 point(s)
# Missing connection between Strada della Campagna and Via Giovanni Battista Gandino at 1 point(s)
# Missing connection between Via Cerrione and Via Giovanni Battista Gandino at 1 point(s)
# Missing connection between Via Giovanni Battista Gandino and Via Giuseppe di Rovasenda at 2 point(s)
# Missing connection between Piazza Moncenisio and Via Luigi Cibrario at 2 point(s)
# Missing connection between Corso Giuseppe Siccardi and Passeggiata Marco Pannella at 1 point(s)
# Missing connection between Corso Cadore and Via Verbano at 1 point(s)
# Missing connection between Ciclabile Carducci - Biglieri and Corso Spezia at 2 point(s)
# Missing connection between Via Gaspero Barbera and Via Portofino at 1 point(s)
# Missing connection between Via Gaspero Barbera and Via Ignazio Isler at 1 point(s)
# Missing connection between Via Arturo Farinelli and Via Domenico Coggiola at 2 point(s)
# Missing connection between Via Arturo Farinelli and Via Rodolfo Morandi at 2 point(s)
# Missing connection between Corso Palermo and Via Perugia at 2 point(s)
# Missing connection between Corso Brescia and Via Perugia at 1 point(s)
# Missing connection between Corso Quintino Sella and Via Tonco at 1 point(s)
# Missing connection between Corso Brescia and Via Carlo Pedrotti at 1 point(s)
# Missing connection between Strada Moncalieri and Strada Revigliasco at 1 point(s)
# Missing connection between Strada Revigliasco and Strada Revigliasco, 251 at 1 point(s)
# Missing connection between Via Giulia di Barolo and Via Giuseppe Verdi at 1 point(s)
# Missing connection between Via Giuseppe Verdi and Via Vanchiglia at 1 point(s)
# Missing connection between Via Don Giovanni Battista Sapino and Via Luigi Battan at 1 point(s)
# Missing connection between Piazza Diciotto Dicembre and Via Cernaia at 1 point(s)
# Missing connection between Via Giovanni Fattori and Via Monte Asolone at 2 point(s)
# Missing connection between Corso Giovanni Pascoli and Piazzale Costantino Il Grande at 2 point(s)
# Missing connection between Strada Settimo and Via Umbria at 1 point(s)
# Missing connection between Strada Borgata Paradiso and Strada San Giorgio at 1 point(s)
# Missing connection between Corso Belgio and Corso Brianza at 3 point(s)
# Missing connection between Via Balangero and Via Nole at 2 point(s)
# Missing connection between Via Italo Pizzi and Via Pio VII at 1 point(s)
# Missing connection between Corso Gaetano Scirea and Strada della Continassa at 3 point(s)
# Missing connection between Piazza Pietro Francesco Guala and Via Piobesi at 1 point(s)
# Missing connection between Via Fratel Teodoreto and Via Piobesi at 1 point(s)
# Missing connection between Via Giulio Gianelli and Via Piobesi at 1 point(s)
# Missing connection between Pista ciclabile di Corso Romania and Via Florence Nightingale at 2 point(s)
# Missing connection between Strada Vicinale dell'Abbadia di Stura and Via Florence Nightingale at 1 point(s)
# Missing connection between Via Evangelina Gemma Alciati and Via Florence Nightingale at 1 point(s)
# Missing connection between Via Monviso and Via Torino at 1 point(s)
# Missing connection between Via Musinet and Via Torino at 1 point(s)
# Missing connection between Via Moncenisio and Via Torino at 1 point(s)
# Missing connection between Via Dora and Via Torino at 1 point(s)
# Missing connection between Via Tetti Ardore and Via Torino at 1 point(s)
# Missing connection between Via Monterosa and Via Torino at 1 point(s)
# Missing connection between Sovrapasso Rigola and Viale delle Industrie at 1 point(s)
# Missing connection between Corso Giuseppe Garibaldi and Via Antonio Colombo at 1 point(s)
# Missing connection between Strada dell'Aeroporto and Via Paolo Veronese at 2 point(s)
# Missing connection between Strada dell'Aeroporto and Strada della Campagna at 1 point(s)
# Missing connection between Strada Bellacomba and Strada dell'Aeroporto at 1 point(s)
# Missing connection between Largo Leonardo da Vinci and Via San Giovanni Bosco at 1 point(s)
# Missing connection between Via Primo Maggio and Via San Giovanni Bosco at 1 point(s)
# Missing connection between Piazza Omero and Via Paolo Gaidano at 1 point(s)
# Missing connection between Corso Mortara and Sottopasso Carlo Donat Cattin at 3 point(s)
# Missing connection between Via Nichelino and Via Villadeati at 2 point(s)
# Missing connection between Via Nichelino and Via Onorato Vigliani at 1 point(s)
# Missing connection between Strada Mongreno and Strada di Sassi at 1 point(s)
# Missing connection between Piazza Madonna dell'Arco and Via Luigi Einaudi at 1 point(s)
# Missing connection between Via Guerrino Nicoli and Via Luigi Einaudi at 1 point(s)
# Missing connection between Corso Stati Uniti and Via San Secondo at 1 point(s)
# Missing connection between Via Fratelli Bandiera and Via Pier Carlo Boggio at 1 point(s)
# Missing connection between Corso Eusebio Giambone and Via Giovanni Michele Graneri at 1 point(s)
# Missing connection between Via Gabriele D'Annunzio and Via Paolo Braccini at 2 point(s)
# Missing connection between Via Gabriele D'Annunzio and Via Spalato at 3 point(s)
# Missing connection between Corso Traiano and Via Matteo Bartoli at 1 point(s)
# Missing connection between Corso Tirreno and Strada dell'Arco at 1 point(s)
# Missing connection between Via Federico Ozanam and Via Po at 1 point(s)
# Missing connection between Ciclabile via Gorizia and Via Baltimora at 2 point(s)
# Missing connection between Via Corrado Corradino and Via Genova at 2 point(s)
# Missing connection between Pronto Soccorso - Emergency and Via Ignazio Porro at 1 point(s)
# Missing connection between Strada Borgata Paradiso and Via Cascina San Giorgio at 1 point(s)
# Missing connection between Strada del Meisino and Via San Giuseppe Cafasso at 1 point(s)
# Missing connection between Corso Sicilia and Via Grado at 1 point(s)
# Missing connection between Corso Sicilia and Via Aquileia at 1 point(s)
# Missing connection between Corso Brescia and Corso Palermo at 2 point(s)
# Missing connection between Corso Palermo and Via Favria at 1 point(s)
# Missing connection between Corso Palermo and Via Barbania at 1 point(s)
# Missing connection between Corso Palermo and Via Baltea at 1 point(s)
# Missing connection between Strada Eremo and Strà di Arsete at 1 point(s)
# Missing connection between Corso Giambattista Beccaria and Giardino Ezio Bosso at 1 point(s)
# Missing connection between Corso Potenza and Largo Grosseto at 1 point(s)
# Missing connection between Via Mercanti and Via Pietro Micca at 1 point(s)
# Missing connection between Via Stradella and Viale Madonna di Campagna at 1 point(s)
# Missing connection between Piazza Generale Antonio Baldissera and Via Antonio Cecchi at 1 point(s)
# Missing connection between Via Andrea Cesalpino and Via Belgirate at 1 point(s)
# Missing connection between Spina Reale and Via Andrea Cesalpino at 1 point(s)
# Missing connection between Via Andrea Cesalpino and Via Stresa at 1 point(s)
# Missing connection between Corso Brescia and Corso Verona at 1 point(s)
# Missing connection between Corso Brescia and Largo Maurizio Vitale at 2 point(s)
# Missing connection between Corso Sebastopoli and Via Tripoli at 3 point(s)
# Missing connection between Corso Sebastopoli and Via Carlo Castelnuovo delle Lanze at 1 point(s)
# Missing connection between Corso Piemonte and Via Monviso at 2 point(s)
# Missing connection between Corso Piemonte and Via della Costituzione at 1 point(s)
# Missing connection between Corso Piemonte and Via Consolata at 1 point(s)
# Missing connection between Corso Piemonte and Via Pian del Re at 1 point(s)
# Missing connection between Corso Piemonte and Via Leinì at 1 point(s)
# Missing connection between Via Felice Casorati and Via Pio VII at 1 point(s)
# Missing connection between Via Pier Domenico Olivero and Via Pio VII at 1 point(s)
# Missing connection between Strada Mongreno and Via San Raffaele at 1 point(s)
# Missing connection between Strada Eremo and Viale Poly D'Aquen at 1 point(s)
# Missing connection between Strada Cunioli Alti and Strada dei Cunioli Alti at 1 point(s)
# Missing connection between Via Zubiena and Viale Madonna di Campagna at 2 point(s)
# Missing connection between Piazzetta Giorgio Perlasca and Via Ivrea at 2 point(s)
# Missing connection between Via Ludovico Bellardi and Via Valgioie at 1 point(s)
# Missing connection between Largo Valgioie and Via Valgioie at 2 point(s)
# Missing connection between Via Carlo Capelli and Via Valgioie at 1 point(s)
# Missing connection between Via Carlo Bianco and Via Paolo Bentivoglio at 1 point(s)
# Missing connection between Corso Ciro Menotti and Via Pier Carlo Boggio at 1 point(s)
# Missing connection between Via Chiesa della Salute and Via Orbetello at 1 point(s)
# Missing connection between Via Ribordone and Via Strambino at 1 point(s)
# Missing connection between Via Fratelli Carando and Via Tripoli at 1 point(s)
# Missing connection between Via Andrea Costaguta and Via Livorno at 1 point(s)
# Missing connection between Corso Trieste and Via Primo Maggio at 2 point(s)
# Missing connection between Corso Trieste and Largo Leonardo da Vinci at 2 point(s)
# Missing connection between Via Don Giovanni Battista Sapino and Via Don Sapino at 2 point(s)
# Missing connection between Strada Militare Carlo Grassi and Via Don Giovanni Battista Sapino at 1 point(s)
# Missing connection between Via Luigi Cibrario and Via Michele Schina at 1 point(s)
# Missing connection between Via Antonio Vagnone and Via Luigi Cibrario at 1 point(s)
# Missing connection between Via Luigi Cibrario and corso Alessandro Tassoni at 1 point(s)
# Missing connection between Via Luigi Cibrario and Via Netro at 1 point(s)
# Missing connection between Via Corio and Via Luigi Cibrario at 1 point(s)
# Missing connection between Piazza Giuseppe Perotti and Via Luigi Cibrario at 1 point(s)
# Missing connection between Via Pavarolo and Via Torre Pellice at 1 point(s)
# Missing connection between Via Annibale Caro and Via Torre Pellice at 1 point(s)
# Missing connection between Strada del Lauro and Strada della Lauretta at 1 point(s)
# Missing connection between Strada Orbassano and Via Giorgio Amendola at 1 point(s)
# Missing connection between Corso Inghilterra and Sottopasso Statuto at 2 point(s)
# Missing connection between Corso Vinzaglio and Via Fratelli Ruffini at 1 point(s)
# Missing connection between Corso Vinzaglio and Via Gaspare Gozzi at 1 point(s)
# Missing connection between Corso Vinzaglio and Via Giuseppe Giusti at 1 point(s)
# Missing connection between Via Abate Antonio Vassalli-Eandi and Via Duchessa Jolanda at 1 point(s)
# Missing connection between Piazza Brennero and Piazza Enrico Mollo at 1 point(s)
# Missing connection between Strada Rosario Scalero and Strada Torino at 1 point(s)
# Missing connection between Strada Torino and Strada Torino 32 at 1 point(s)
# Missing connection between Corso Vigevano and Piazza Generale Antonio Baldissera at 1 point(s)
# Missing connection between Corso Vigevano and Piazza Francesco Crispi at 1 point(s)
# Missing connection between Corso Giulio Cesare 424 and Pista ciclabile di Corso Giulio Cesare at 3 point(s)
# Missing connection between Via Benvenuto Cellini and Via Canova at 1 point(s)
# Missing connection between Strada da Villaretto a Borgaro and Via Benvenuto Cellini at 1 point(s)
# Missing connection between Via degli Aceri and Via dei Frassini at 1 point(s)
# Missing connection between Strada della Barberina and Via Cuorgnè at 1 point(s)
# Missing connection between Via degli Aceri and Via delle Betulle at 2 point(s)
# Missing connection between Strada della Manta and Via Carlo Abarth at 1 point(s)
# Missing connection between Corso Cavour and Via Trucchi at 2 point(s)
# Missing connection between Chiesetta 2 and Strada Maddalena at 1 point(s)
# Missing connection between Strada Gavoni and Strada Maddalena at 1 point(s)
# Missing connection between Strada Maddalena and Via Col di Cadibona at 1 point(s)
# Missing connection between Bullet and Strada Maddalena at 1 point(s)
# Missing connection between Strada Maddalena and Strada Rondapaletto at 1 point(s)
# Missing connection between Strada Maddalena and Strada Paniasso at 1 point(s)
# Missing connection between Strada Maddalena and Via Baricco at 2 point(s)
# Missing connection between Via Augusto Nomis Di Cossilla and Via Giovanni Chevalley at 1 point(s)
# Missing connection between Piazzetta Vittime del Genocidio dei Tutsi and Via Giovanni Battista e Carlo Felice Biscarra at 1 point(s)
# Missing connection between Corso Vinzaglio and Via San Quintino at 1 point(s)
# Missing connection between Corso Palestro and Via Giuseppe Garibaldi at 1 point(s)
# Missing connection between Via Ciamarella and Via Montesoglio at 1 point(s)
# Missing connection between Via Barnaba Panizza and Via Giuseppe Romita at 1 point(s)
# Missing connection between Via Giacomo Balla and Via Giuseppe Romita at 6 point(s)
# Missing connection between Via Giacomo Balla and Via Pietro Canonica at 1 point(s)
# Missing connection between Via Giuseppe Romita and Via Pietro Canonica at 1 point(s)
# Missing connection between Via Castagneri and Via Ernesto Casagrande at 1 point(s)
# Missing connection between Via Marzabotto and Via Staffette Partigiane at 1 point(s)
# Missing connection between Via Camogli and Via Carlo Forlanini at 1 point(s)
# Missing connection between Via Bainsizza and Via Leopoldo Lanfranco at 1 point(s)
# Missing connection between Via Fratelli Carando and Via Leopoldo Lanfranco at 2 point(s)
# Missing connection between Piazza Ghirlandaio and Via Francesco Cigna at 1 point(s)
# Missing connection between Via Moncenisio and Via delle Fonderie at 1 point(s)
# Missing connection between Via Gran Paradiso and Via Gran San Bernardo at 1 point(s)
# Missing connection between Via Gran Paradiso and Via Valle Stretta at 1 point(s)
# Missing connection between Via Nole and Via Pietro Thouar at 1 point(s)
# Missing connection between Piazza C.L.N. and Piazza CLN at 2 point(s)
# Missing connection between Piazzetta Andrea Viglongo and Via Stampatori at 1 point(s)
# Missing connection between Pista ciclabile di Corso Giulio Cesare and Pista ciclopedonale del Parco dell'Arrivore at 1 point(s)
# Missing connection between Piazza Derna and Pista ciclabile di Corso Giulio Cesare at 1 point(s)
# Missing connection between Largo Giulio Cesare and Via Volpiano at 1 point(s)
# Missing connection between Piazza Bruno Trentin and Via Cardinale Michele Pellegrino at 1 point(s)
# Missing connection between Piazza Bruno Trentin and Via Carlo Donat Cattin at 1 point(s)
# Missing connection between Piazzetta Don Giuseppe Puglisi and Strada del Villaretto at 1 point(s)
# Missing connection between Corso Principe Oddone and Sottopasso Statuto at 2 point(s)
# Missing connection between Via Maddalene and Via San Benigno at 1 point(s)
# Missing connection between Lungo Dora Voghera and Via Asigliano Vercellese at 1 point(s)
# Missing connection between Largo Valgioie and Via Carlo Capelli at 2 point(s)
# Missing connection between Piazza Europa and Piazzale Europa at 1 point(s)
# Missing connection between Lungo Dora Agrigento and Piazzetta Vittime dello Stadio Heysel at 6 point(s)
# Missing connection between Lungo Dora Agrigento and Piazzetta Umberto Terracini at 6 point(s)
# Missing connection between Pista ciclabile di Corso Romania and Via Evangelina Gemma Alciati at 1 point(s)
# 100%|██████████| 558/558 [00:15<00:00, 34.96it/s]
# 100%|██████████| 3521/3521 [00:48<00:00, 72.29it/s]
# Merging lines: 100%|██████████| 4040/4040 [00:00<00:00, 5406.80it/s]
# Extracting intersections: 100%|██████████| 6486/6486 [00:04<00:00, 1563.65it/s]
# Processing edges: 100%|██████████| 3438/3438 [00:05<00:00, 589.34it/s]
# Merging lines: 100%|██████████| 3882/3882 [00:00<00:00, 4456.49it/s]
# Extracting intersections: 100%|██████████| 6268/6268 [00:03<00:00, 1874.63it/s]
# Processing edges: 100%|██████████| 1411/1411 [00:01<00:00, 809.51it/s]
# Merging lines: 100%|██████████| 3876/3876 [00:00<00:00, 6372.07it/s]
# Extracting intersections: 100%|██████████| 6321/6321 [00:03<00:00, 2101.79it/s]
# 91 duplicates were removed
